# %%
import pandas as pd
from transformers import TFBertForSequenceClassification, BertTokenizer
import torch
import tensorflow as tf
from tensorflow.nn import softmax
from tensorflow.math import reduce_mean
import numpy as np
from sklearn.model_selection import train_test_split
from datasets import Dataset
from datasets import flatten_nest_dict
import tensorflow_text as text
import tensorflow_hub as hub

# %%
data = pd.read_csv("../../data/sensitivity_data/sensitivity_dataset.csv")
data = data[["Document","Sensitivity"]]

test_data = data.sample(1)["Document"].values[0]
test_data_label = data.sample(1)["Sensitivity"].values[0]
test_data_label

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
model = TFBertForSequenceClassification.from_pretrained("bert-base-cased",num_labels=2)
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokens = tokenizer.encode_plus(test_data, add_special_tokens=False,return_tensors="pt")

# %%
input_ids_chunks = tokens["input_ids"][0].split(510)
mask_chunks = tokens["attention_mask"][0].split(510)

for tensor in input_ids_chunks:
    print(len(tensor))

# %%
chunksize = 512
input_ids_chunks = list(input_ids_chunks)
mask_chunks = list(mask_chunks)

for i in range(len(input_ids_chunks)):
    input_ids_chunks[i] = torch.cat([torch.Tensor([101]),input_ids_chunks[i],torch.Tensor([102])])
    mask_chunks[i] = torch.cat([torch.Tensor([1]),mask_chunks[i],torch.Tensor([1])])

    pad_len = chunksize - input_ids_chunks[i].shape[0]
    if pad_len > 0:
        input_ids_chunks[i] = torch.cat([input_ids_chunks[i], torch.Tensor([0] * pad_len)])
        mask_chunks[i] = torch.cat([mask_chunks[i], torch.Tensor([0] * pad_len)])

for tensor in input_ids_chunks:
    print(len(tensor))

tensor

# %%
input_ids = torch.stack(input_ids_chunks)
attention_mask = torch.stack(mask_chunks)

np_tensor = input_ids.numpy()
input_ids = tf.convert_to_tensor(np_tensor)
input_ids = tf.cast(input_ids, tf.int64)

np_tensor = attention_mask.numpy()
attention_mask = tf.convert_to_tensor(np_tensor)
attention_mask = tf.cast(attention_mask, tf.int32)

input_dict = {'input_ids' : input_ids,'attention_mask':attention_mask}

input_dict

# %%
outputs = model(**input_dict)
outputs

# %%
probs = tf.nn.softmax(outputs[0],axis=-1)
mean = tf.math.reduce_mean(probs,axis=0)

mean

# %%
######################################
## TRAIN MODEL ON THIS CHUNKED BERT ##
######################################

# %%
def chunked_tokenise(txt):
    tokens = tokenizer.encode_plus(txt, add_special_tokens=False,return_tensors="pt")

    input_ids_chunks = tokens["input_ids"][0].split(510)
    mask_chunks = tokens["attention_mask"][0].split(510)

    chunksize = 512
    input_ids_chunks = list(input_ids_chunks)
    mask_chunks = list(mask_chunks)

    for i in range(len(input_ids_chunks)):
        input_ids_chunks[i] = torch.cat([torch.Tensor([101]),input_ids_chunks[i],torch.Tensor([102])])
        mask_chunks[i] = torch.cat([torch.Tensor([1]),mask_chunks[i],torch.Tensor([1])])

        pad_len = chunksize - input_ids_chunks[i].shape[0]
        if pad_len > 0:
            input_ids_chunks[i] = torch.cat([input_ids_chunks[i], torch.Tensor([0] * pad_len)])
            mask_chunks[i] = torch.cat([mask_chunks[i], torch.Tensor([0] * pad_len)])

    input_ids = torch.stack(input_ids_chunks)
    attention_mask = torch.stack(mask_chunks)

    np_tensor = input_ids.numpy()
    input_ids = tf.convert_to_tensor(np_tensor)
    input_ids = tf.cast(input_ids, tf.int64)

    np_tensor = attention_mask.numpy()
    attention_mask = tf.convert_to_tensor(np_tensor)
    attention_mask = tf.cast(attention_mask, tf.int32)

    input_dict = {'input_ids' : input_ids,'attention_mask':attention_mask}
    return input_dict

# %%
data = pd.read_csv("../../data/sensitivity_data/sensitivity_dataset.csv")
data = data[["Document","Sensitivity"]]

train_x, test_x, train_y, test_y = train_test_split(data['Document'],data['Sensitivity'],test_size=0.2,random_state=5)
train_x = np.array(train_x)
train_y = np.array(train_y)

dataset = []
for i in range(len(train_x)):
    dataset.append({"label" : train_y[i], "text" : train_x[i]})

dataset = pd.DataFrame(dataset)
dataset = Dataset.from_pandas(dataset)

def preprocess_function(examples):
    return chunked_tokenise(examples["text"])

tokenised_dataset = dataset.map(preprocess_function, batched=False)
tokenised_dataset.features['input_ids'] = tokenised_dataset.features['input_ids'].feature
tokenised_dataset.features['attention_mask'] = tokenised_dataset.features['attention_mask'].feature
tokenised_dataset.features

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer, return_tensors="tf")

tf_train_dataset = tokenised_dataset.to_tf_dataset(
    columns=['attention_mask', 'input_ids', 'label'],
    label_cols=['label'],
    shuffle=True,
    batch_size=1,
    collate_fn=data_collator,
)

# %%
from transformers import create_optimizer
import tensorflow as tf

batch_size = 16
num_epochs = 5
batches_per_epoch = len(tf_train_dataset) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(
    init_lr=2e-5, 
    num_warmup_steps=0, 
    num_train_steps=total_train_steps
)

# %%
model.compile(loss="binary_crossentropy",optimizer=optimizer)
model.fit(tf_train_dataset,epochs=5)

# %%
##############################################
## ATTEMPT MANUAL MODEL USING POOLER OUTPUT ##
##############################################

# %%
data = pd.read_csv("../../data/sensitivity_data/sensitivity_dataset.csv")
data = data[["Document","Sensitivity"]]

train_x, test_x, train_y, test_y = train_test_split(data['Document'],data['Sensitivity'],test_size=0.2,random_state=5)
train_x = np.array(train_x)
train_y = np.array(train_y)
test_x = np.array(test_x)
test_y = np.array(test_y)

# %%
###################################
## UNDERSAMPLED BALANCED DATASET ##
###################################

data = pd.read_csv("../../data/sensitivity_data/sensitivity_dataset.csv")
data = data[["Document","Sensitivity"]]

train_x, test_x, train_y, test_y = train_test_split(data['Document'],data['Sensitivity'],test_size=0.2,random_state=5)
train_x = pd.DataFrame([train_x,train_y]).T

classes_zero = train_x[train_x['Sensitivity'] == 0]
classes_one = train_x[train_x['Sensitivity'] == 1]

classes_zero = classes_zero.sample(len(classes_one))

undersampled_dataset = pd.concat([classes_zero,classes_one])
undersampled_dataset = undersampled_dataset.sample(frac=1, random_state=42).reset_index(drop=True)

train_x = np.array(undersampled_dataset["Document"])
train_y = np.array(undersampled_dataset["Sensitivity"])
train_y = tf.convert_to_tensor(train_y,dtype=tf.float32)

# %%
###################################
## OVERSAMPLED BALANCED DATASET ##
###################################

data = pd.read_csv("../../data/sensitivity_data/sensitivity_dataset.csv")
data = data[["Document","Sensitivity"]]

train_x, test_x, train_y, test_y = train_test_split(data['Document'],data['Sensitivity'],test_size=0.2,random_state=5)
train_x = pd.DataFrame([train_x,train_y]).T

classes_zero = train_x[train_x['Sensitivity'] == 0]
classes_one = train_x[train_x['Sensitivity'] == 1]
print(len(classes_zero),len(classes_one))

classes_one = classes_one.sample(len(classes_zero), replace=True)

oversampled_dataset = pd.concat([classes_zero,classes_one])
oversampled_dataset = oversampled_dataset.sample(frac=1, random_state=42).reset_index(drop=True)

train_x = np.array(oversampled_dataset["Document"])
train_y = np.array(oversampled_dataset["Sensitivity"])
train_y = tf.convert_to_tensor(train_y,dtype=tf.float32)

# %%
tfhub_handle_encoder = 'https://tfhub.dev/tensorflow/bert_en_cased_L-12_H-768_A-12/3'
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
model = TFBertForSequenceClassification.from_pretrained("bert-base-cased",num_labels=2)
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#bert_model = hub.KerasLayer(tfhub_handle_encoder,trainable=False)
def get_pooled_outputs(txt):
    inputs = chunked_tokenise(txt)
    model_outputs = model(**inputs,output_hidden_states=True)
    hidden_states = model_outputs.hidden_states
    len_list= np.arange(0,len(hidden_states))
    pooled_output = tf.concat(tuple([hidden_states[i] for i in len_list]), axis=-1)
    pooled_output = pooled_output[:, 0, :]
    #pooled_output = tf.reduce_mean(pooled_output,axis=0)
    return pooled_output


pooled_outputs = []
i = 1
for sample in train_x:
    pooled_outputs.append(get_pooled_outputs(sample))
    print(str(i) + " Documents Processed..." + str( round( (i/len(train_x)) * 100, 2)) + "%")
    i += 1

# %%
tester = pooled_outputs
averaged_tester = []
for elt in tester:
    averaged_tester.append(np.mean(elt,axis=0))

averaged_tester = tf.convert_to_tensor(averaged_tester)
averaged_tester.shape

# %%
def elt_wise_mean(x):
    return tf.convert_to_tensor(np.mean(x,axis=0))

class Chunk(tf.keras.layers.Layer):
    def __init__(self, input_dim):
        super(Chunk, self).__init__()

    def call(self, inputs):
        return chunked_tokenise(inputs)

class Model_Call(tf.keras.layers.Layer):
    def __init__(self):
        super(Model_Call, self).__init__()

    def call(self, inputs):
        return model(**inputs)

def model_call(encoder_inputs):
    return model(**encoder_inputs)

pooled_input = tf.keras.layers.Input(shape=(9984,), dtype=tf.float32, name='Pooled Input')
dense = tf.keras.layers.Dense(2, activation='softmax', input_dim=1, name='Dense')(pooled_input)

model = tf.keras.Model(pooled_input, dense)
model.summary()

# %%
from transformers import create_optimizer
import tensorflow as tf

optimiser = tf.optimizers.Adam(learning_rate= 5e-5)
#BINARY CROSSENTROPY SHOULD BE HERE, NO?
model.compile(loss="sparse_categorical_crossentropy",optimizer=optimiser)

# %%
model.fit(averaged_tester,train_y,epochs=5,batch_size=1)

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import precision_score
from sklearn.metrics import make_scorer

test_pooled_outputs = []
i = 1
for sample in test_x:
    test_pooled_outputs.append(get_pooled_outputs(sample))
    print(str(i) + " Documents Processed..." + str( round( (i/len(test_x)) * 100, 2)) + "%")
    i += 1

# %%
test_samples = []
for elt in test_pooled_outputs:
    test_samples.append(np.mean(elt,axis=0))

test_samples = tf.convert_to_tensor(test_samples)

# %%
predictions = model.predict(test_samples)
bin_preds = []
for pred in predictions:
    if pred[1] > pred[0]:
        bin_preds.append(1)
    else:
        bin_preds.append(0)

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import precision_score
from sklearn.metrics import make_scorer

precision = precision_score(test_y, bin_preds)
bac = balanced_accuracy_score(test_y, bin_preds)
f2 = fbeta_score(test_y, bin_preds, beta=2.0)
print(precision,bac,f2)

# %%
######################################################
## TRY TO MAKE SURE USING ALL OF THE POOLED OUTPUTS ##
######################################################

# %%
def get_pooled_outputs_v2(txt):
    complete_pooled_outputs = []
    inputs = chunked_tokenise(txt)
    model_outputs = model(**inputs,output_hidden_states=True)
    hidden_states = model_outputs.hidden_states
    for i in range(len(hidden_states)):
        for j in range(len(hidden_states[i])):
            complete_pooled_outputs.append(hidden_states[i][j])

    complete_pooled_outputs = tf.convert_to_tensor(complete_pooled_outputs)
    return tf.reduce_mean(complete_pooled_outputs,axis=0)

pooled_outputs = []
i = 1
for sample in train_x:
    pooled_outputs.append(get_pooled_outputs_v2(sample))
    print(str(i) + " Documents Processed..." + str( round( (i/len(train_x)) * 100, 2)) + "%")
    i += 1
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1238 > 512). Running this sequence through the model will result in indexing errors
# 1 Documents Processed...0.03%
# 2 Documents Processed...0.07%
# 3 Documents Processed...0.1%
# 4 Documents Processed...0.13%
# 5 Documents Processed...0.16%
# 6 Documents Processed...0.2%
# 7 Documents Processed...0.23%
# 8 Documents Processed...0.26%
# 9 Documents Processed...0.3%
# 10 Documents Processed...0.33%
# 11 Documents Processed...0.36%
# 12 Documents Processed...0.39%
# 13 Documents Processed...0.43%
# 14 Documents Processed...0.46%
# 15 Documents Processed...0.49%
# 16 Documents Processed...0.53%
# 17 Documents Processed...0.56%
# 18 Documents Processed...0.59%
# 19 Documents Processed...0.62%
# 20 Documents Processed...0.66%
# 21 Documents Processed...0.69%
# 22 Documents Processed...0.72%
# 23 Documents Processed...0.76%
# 24 Documents Processed...0.79%
# 25 Documents Processed...0.82%
# 26 Documents Processed...0.86%
# 27 Documents Processed...0.89%
# 28 Documents Processed...0.92%
# 29 Documents Processed...0.95%
# 30 Documents Processed...0.99%
# 31 Documents Processed...1.02%
# 32 Documents Processed...1.05%
# 33 Documents Processed...1.09%
# 34 Documents Processed...1.12%
# 35 Documents Processed...1.15%
# 36 Documents Processed...1.18%
# 37 Documents Processed...1.22%
# 38 Documents Processed...1.25%
# 39 Documents Processed...1.28%
# 40 Documents Processed...1.32%
# 41 Documents Processed...1.35%
# 42 Documents Processed...1.38%
# 43 Documents Processed...1.41%
# 44 Documents Processed...1.45%
# 45 Documents Processed...1.48%
# 46 Documents Processed...1.51%
# 47 Documents Processed...1.55%
# 48 Documents Processed...1.58%
# 49 Documents Processed...1.61%
# 50 Documents Processed...1.64%
# 51 Documents Processed...1.68%
# 52 Documents Processed...1.71%
# 53 Documents Processed...1.74%
# 54 Documents Processed...1.78%
# 55 Documents Processed...1.81%
# 56 Documents Processed...1.84%
# 57 Documents Processed...1.88%
# 58 Documents Processed...1.91%
# 59 Documents Processed...1.94%
# 60 Documents Processed...1.97%
# 61 Documents Processed...2.01%
# 62 Documents Processed...2.04%
# 63 Documents Processed...2.07%
# 64 Documents Processed...2.11%
# 65 Documents Processed...2.14%
# 66 Documents Processed...2.17%
# 67 Documents Processed...2.2%
# 68 Documents Processed...2.24%
# 69 Documents Processed...2.27%
# 70 Documents Processed...2.3%
# 71 Documents Processed...2.34%
# 72 Documents Processed...2.37%
# 73 Documents Processed...2.4%
# 74 Documents Processed...2.43%
# 75 Documents Processed...2.47%
# 76 Documents Processed...2.5%
# 77 Documents Processed...2.53%
# 78 Documents Processed...2.57%
# 79 Documents Processed...2.6%
# 80 Documents Processed...2.63%
# 81 Documents Processed...2.66%
# 82 Documents Processed...2.7%
# 83 Documents Processed...2.73%
# 84 Documents Processed...2.76%
# 85 Documents Processed...2.8%
# 86 Documents Processed...2.83%
# 87 Documents Processed...2.86%
# 88 Documents Processed...2.89%
# 89 Documents Processed...2.93%
# 90 Documents Processed...2.96%
# 91 Documents Processed...2.99%
# 92 Documents Processed...3.03%
# 93 Documents Processed...3.06%
# 94 Documents Processed...3.09%
# 95 Documents Processed...3.12%
# 96 Documents Processed...3.16%
# 97 Documents Processed...3.19%
# 98 Documents Processed...3.22%
# 99 Documents Processed...3.26%
# 100 Documents Processed...3.29%
# 101 Documents Processed...3.32%
# 102 Documents Processed...3.36%
# 103 Documents Processed...3.39%
# 104 Documents Processed...3.42%
# 105 Documents Processed...3.45%
# 106 Documents Processed...3.49%
# 107 Documents Processed...3.52%
# 108 Documents Processed...3.55%
# 109 Documents Processed...3.59%
# 110 Documents Processed...3.62%
# 111 Documents Processed...3.65%
# 112 Documents Processed...3.68%
# 113 Documents Processed...3.72%
# 114 Documents Processed...3.75%
# 115 Documents Processed...3.78%
# 116 Documents Processed...3.82%
# 117 Documents Processed...3.85%
# 118 Documents Processed...3.88%
# 119 Documents Processed...3.91%
# 120 Documents Processed...3.95%
# 121 Documents Processed...3.98%
# 122 Documents Processed...4.01%
# 123 Documents Processed...4.05%
# 124 Documents Processed...4.08%
# 125 Documents Processed...4.11%
# 126 Documents Processed...4.14%
# 127 Documents Processed...4.18%
# 128 Documents Processed...4.21%
# 129 Documents Processed...4.24%
# 130 Documents Processed...4.28%
# 131 Documents Processed...4.31%
# 132 Documents Processed...4.34%
# 133 Documents Processed...4.38%
# 134 Documents Processed...4.41%
# 135 Documents Processed...4.44%
# 136 Documents Processed...4.47%
# 137 Documents Processed...4.51%
# 138 Documents Processed...4.54%
# 139 Documents Processed...4.57%
# 140 Documents Processed...4.61%
# 141 Documents Processed...4.64%
# 142 Documents Processed...4.67%
# 143 Documents Processed...4.7%
# 144 Documents Processed...4.74%
# 145 Documents Processed...4.77%
# 146 Documents Processed...4.8%
# 147 Documents Processed...4.84%
# 148 Documents Processed...4.87%
# 149 Documents Processed...4.9%
# 150 Documents Processed...4.93%
# 151 Documents Processed...4.97%
# 152 Documents Processed...5.0%
# 153 Documents Processed...5.03%
# 154 Documents Processed...5.07%
# 155 Documents Processed...5.1%
# 156 Documents Processed...5.13%
# 157 Documents Processed...5.16%
# 158 Documents Processed...5.2%
# 159 Documents Processed...5.23%
# 160 Documents Processed...5.26%
# 161 Documents Processed...5.3%
# 162 Documents Processed...5.33%
# 163 Documents Processed...5.36%
# 164 Documents Processed...5.39%
# 165 Documents Processed...5.43%
# 166 Documents Processed...5.46%
# 167 Documents Processed...5.49%
# 168 Documents Processed...5.53%
# 169 Documents Processed...5.56%
# 170 Documents Processed...5.59%
# 171 Documents Processed...5.62%
# 172 Documents Processed...5.66%
# 173 Documents Processed...5.69%
# 174 Documents Processed...5.72%
# 175 Documents Processed...5.76%
# 176 Documents Processed...5.79%
# 177 Documents Processed...5.82%
# 178 Documents Processed...5.86%
# 179 Documents Processed...5.89%
# 180 Documents Processed...5.92%
# 181 Documents Processed...5.95%
# 182 Documents Processed...5.99%
# 183 Documents Processed...6.02%
# 184 Documents Processed...6.05%
# 185 Documents Processed...6.09%
# 186 Documents Processed...6.12%
# 187 Documents Processed...6.15%
# 188 Documents Processed...6.18%
# 189 Documents Processed...6.22%
# 190 Documents Processed...6.25%
# 191 Documents Processed...6.28%
# 192 Documents Processed...6.32%
# 193 Documents Processed...6.35%
# 194 Documents Processed...6.38%
# 195 Documents Processed...6.41%
# 196 Documents Processed...6.45%
# 197 Documents Processed...6.48%
# 198 Documents Processed...6.51%
# 199 Documents Processed...6.55%
# 200 Documents Processed...6.58%
# 201 Documents Processed...6.61%
# 202 Documents Processed...6.64%
# 203 Documents Processed...6.68%
# 204 Documents Processed...6.71%
# 205 Documents Processed...6.74%
# 206 Documents Processed...6.78%
# 207 Documents Processed...6.81%
# 208 Documents Processed...6.84%
# 209 Documents Processed...6.88%
# 210 Documents Processed...6.91%
# 211 Documents Processed...6.94%
# 212 Documents Processed...6.97%
# 213 Documents Processed...7.01%
# 214 Documents Processed...7.04%
# 215 Documents Processed...7.07%
# 216 Documents Processed...7.11%
# 217 Documents Processed...7.14%
# 218 Documents Processed...7.17%
# 219 Documents Processed...7.2%
# 220 Documents Processed...7.24%
# 221 Documents Processed...7.27%
# 222 Documents Processed...7.3%
# 223 Documents Processed...7.34%
# 224 Documents Processed...7.37%
# 225 Documents Processed...7.4%
# 226 Documents Processed...7.43%
# 227 Documents Processed...7.47%
# 228 Documents Processed...7.5%
# 229 Documents Processed...7.53%
# 230 Documents Processed...7.57%
# 231 Documents Processed...7.6%
# 232 Documents Processed...7.63%
# 233 Documents Processed...7.66%
# 234 Documents Processed...7.7%
# 235 Documents Processed...7.73%
# 236 Documents Processed...7.76%
# 237 Documents Processed...7.8%
# 238 Documents Processed...7.83%
# 239 Documents Processed...7.86%
# 240 Documents Processed...7.89%
# 241 Documents Processed...7.93%
# 242 Documents Processed...7.96%
# 243 Documents Processed...7.99%
# 244 Documents Processed...8.03%
# 245 Documents Processed...8.06%
# 246 Documents Processed...8.09%
# 247 Documents Processed...8.12%
# 248 Documents Processed...8.16%
# 249 Documents Processed...8.19%
# 250 Documents Processed...8.22%
# 251 Documents Processed...8.26%
# 252 Documents Processed...8.29%
# 253 Documents Processed...8.32%
# 254 Documents Processed...8.36%
# 255 Documents Processed...8.39%
# 256 Documents Processed...8.42%
# 257 Documents Processed...8.45%
# 258 Documents Processed...8.49%
# 259 Documents Processed...8.52%
# 260 Documents Processed...8.55%
# 261 Documents Processed...8.59%
# 262 Documents Processed...8.62%
# 263 Documents Processed...8.65%
# 264 Documents Processed...8.68%
# 265 Documents Processed...8.72%
# 266 Documents Processed...8.75%
# 267 Documents Processed...8.78%
# 268 Documents Processed...8.82%
# 269 Documents Processed...8.85%
# 270 Documents Processed...8.88%
# 271 Documents Processed...8.91%
# 272 Documents Processed...8.95%
# 273 Documents Processed...8.98%
# 274 Documents Processed...9.01%
# 275 Documents Processed...9.05%
# 276 Documents Processed...9.08%
# 277 Documents Processed...9.11%
# 278 Documents Processed...9.14%
# 279 Documents Processed...9.18%
# 280 Documents Processed...9.21%
# 281 Documents Processed...9.24%
# 282 Documents Processed...9.28%
# 283 Documents Processed...9.31%
# 284 Documents Processed...9.34%
# 285 Documents Processed...9.38%
# 286 Documents Processed...9.41%
# 287 Documents Processed...9.44%
# 288 Documents Processed...9.47%
# 289 Documents Processed...9.51%
# 290 Documents Processed...9.54%
# 291 Documents Processed...9.57%
# 292 Documents Processed...9.61%
# 293 Documents Processed...9.64%
# 294 Documents Processed...9.67%
# 295 Documents Processed...9.7%
# 296 Documents Processed...9.74%
# 297 Documents Processed...9.77%
# 298 Documents Processed...9.8%
# 299 Documents Processed...9.84%
# 300 Documents Processed...9.87%
# 301 Documents Processed...9.9%
# 302 Documents Processed...9.93%
# 303 Documents Processed...9.97%
# 304 Documents Processed...10.0%
# 305 Documents Processed...10.03%
# 306 Documents Processed...10.07%
# 307 Documents Processed...10.1%
# 308 Documents Processed...10.13%
# 309 Documents Processed...10.16%
# 310 Documents Processed...10.2%
# 311 Documents Processed...10.23%
# 312 Documents Processed...10.26%
# 313 Documents Processed...10.3%
# 314 Documents Processed...10.33%
# 315 Documents Processed...10.36%
# 316 Documents Processed...10.39%
# 317 Documents Processed...10.43%
# 318 Documents Processed...10.46%
# 319 Documents Processed...10.49%
# 320 Documents Processed...10.53%
# 321 Documents Processed...10.56%
# 322 Documents Processed...10.59%
# 323 Documents Processed...10.62%
# 324 Documents Processed...10.66%
# 325 Documents Processed...10.69%
# 326 Documents Processed...10.72%
# 327 Documents Processed...10.76%
# 328 Documents Processed...10.79%
# 329 Documents Processed...10.82%
# 330 Documents Processed...10.86%
# 331 Documents Processed...10.89%
# 332 Documents Processed...10.92%
# 333 Documents Processed...10.95%
# 334 Documents Processed...10.99%
# 335 Documents Processed...11.02%
# 336 Documents Processed...11.05%
# 337 Documents Processed...11.09%
# 338 Documents Processed...11.12%
# 339 Documents Processed...11.15%
# 340 Documents Processed...11.18%
# 341 Documents Processed...11.22%
# 342 Documents Processed...11.25%
# 343 Documents Processed...11.28%
# 344 Documents Processed...11.32%
# 345 Documents Processed...11.35%
# 346 Documents Processed...11.38%
# 347 Documents Processed...11.41%
# 348 Documents Processed...11.45%
# 349 Documents Processed...11.48%
# 350 Documents Processed...11.51%
# 351 Documents Processed...11.55%
# 352 Documents Processed...11.58%
# 353 Documents Processed...11.61%
# 354 Documents Processed...11.64%
# 355 Documents Processed...11.68%
# 356 Documents Processed...11.71%
# 357 Documents Processed...11.74%
# 358 Documents Processed...11.78%
# 359 Documents Processed...11.81%
# 360 Documents Processed...11.84%
# 361 Documents Processed...11.88%
# 362 Documents Processed...11.91%
# 363 Documents Processed...11.94%
# 364 Documents Processed...11.97%
# 365 Documents Processed...12.01%
# 366 Documents Processed...12.04%
# 367 Documents Processed...12.07%
# 368 Documents Processed...12.11%
# 369 Documents Processed...12.14%
# 370 Documents Processed...12.17%
# 371 Documents Processed...12.2%
# 372 Documents Processed...12.24%
# 373 Documents Processed...12.27%
# 374 Documents Processed...12.3%
# 375 Documents Processed...12.34%
# 376 Documents Processed...12.37%
# 377 Documents Processed...12.4%
# 378 Documents Processed...12.43%
# 379 Documents Processed...12.47%
# 380 Documents Processed...12.5%
# 381 Documents Processed...12.53%
# 382 Documents Processed...12.57%
# 383 Documents Processed...12.6%
# 384 Documents Processed...12.63%
# 385 Documents Processed...12.66%
# 386 Documents Processed...12.7%
# 387 Documents Processed...12.73%
# 388 Documents Processed...12.76%
# 389 Documents Processed...12.8%
# 390 Documents Processed...12.83%
# 391 Documents Processed...12.86%
# 392 Documents Processed...12.89%
# 393 Documents Processed...12.93%
# 394 Documents Processed...12.96%
# 395 Documents Processed...12.99%
# 396 Documents Processed...13.03%
# 397 Documents Processed...13.06%
# 398 Documents Processed...13.09%
# 399 Documents Processed...13.12%
# 400 Documents Processed...13.16%
# 401 Documents Processed...13.19%
# 402 Documents Processed...13.22%
# 403 Documents Processed...13.26%
# 404 Documents Processed...13.29%
# 405 Documents Processed...13.32%
# 406 Documents Processed...13.36%
# 407 Documents Processed...13.39%
# 408 Documents Processed...13.42%
# 409 Documents Processed...13.45%
# 410 Documents Processed...13.49%
# 411 Documents Processed...13.52%
# 412 Documents Processed...13.55%
# 413 Documents Processed...13.59%
# 414 Documents Processed...13.62%
# 415 Documents Processed...13.65%
# 416 Documents Processed...13.68%
# 417 Documents Processed...13.72%
# 418 Documents Processed...13.75%
# 419 Documents Processed...13.78%
# 420 Documents Processed...13.82%
# 421 Documents Processed...13.85%
# 422 Documents Processed...13.88%
# 423 Documents Processed...13.91%
# 424 Documents Processed...13.95%
# 425 Documents Processed...13.98%
# 426 Documents Processed...14.01%
# 427 Documents Processed...14.05%
# 428 Documents Processed...14.08%
# 429 Documents Processed...14.11%
# 430 Documents Processed...14.14%
# 431 Documents Processed...14.18%
# 432 Documents Processed...14.21%
# 433 Documents Processed...14.24%
# 434 Documents Processed...14.28%
# 435 Documents Processed...14.31%
# 436 Documents Processed...14.34%
# 437 Documents Processed...14.37%
# 438 Documents Processed...14.41%
# 439 Documents Processed...14.44%
# 440 Documents Processed...14.47%
# 441 Documents Processed...14.51%
# 442 Documents Processed...14.54%
# 443 Documents Processed...14.57%
# 444 Documents Processed...14.61%
# 445 Documents Processed...14.64%
# 446 Documents Processed...14.67%
# 447 Documents Processed...14.7%
# 448 Documents Processed...14.74%
# 449 Documents Processed...14.77%
# 450 Documents Processed...14.8%
# 451 Documents Processed...14.84%
# 452 Documents Processed...14.87%
# 453 Documents Processed...14.9%
# 454 Documents Processed...14.93%
# 455 Documents Processed...14.97%
# 456 Documents Processed...15.0%
# 457 Documents Processed...15.03%
# 458 Documents Processed...15.07%
# 459 Documents Processed...15.1%
# 460 Documents Processed...15.13%
# 461 Documents Processed...15.16%
# 462 Documents Processed...15.2%
# 463 Documents Processed...15.23%
# 464 Documents Processed...15.26%
# 465 Documents Processed...15.3%
# 466 Documents Processed...15.33%
# 467 Documents Processed...15.36%
# 468 Documents Processed...15.39%
# 469 Documents Processed...15.43%
# 470 Documents Processed...15.46%
# 471 Documents Processed...15.49%
# 472 Documents Processed...15.53%
# 473 Documents Processed...15.56%
# 474 Documents Processed...15.59%
# 475 Documents Processed...15.62%
# 476 Documents Processed...15.66%
# 477 Documents Processed...15.69%
# 478 Documents Processed...15.72%
# 479 Documents Processed...15.76%
# 480 Documents Processed...15.79%
# 481 Documents Processed...15.82%
# 482 Documents Processed...15.86%
# 483 Documents Processed...15.89%
# 484 Documents Processed...15.92%
# 485 Documents Processed...15.95%
# 486 Documents Processed...15.99%
# 487 Documents Processed...16.02%
# 488 Documents Processed...16.05%
# 489 Documents Processed...16.09%
# 490 Documents Processed...16.12%
# 491 Documents Processed...16.15%
# 492 Documents Processed...16.18%
# 493 Documents Processed...16.22%
# 494 Documents Processed...16.25%
# 495 Documents Processed...16.28%
# 496 Documents Processed...16.32%
# 497 Documents Processed...16.35%
# 498 Documents Processed...16.38%
# 499 Documents Processed...16.41%
# 500 Documents Processed...16.45%
# 501 Documents Processed...16.48%
# 502 Documents Processed...16.51%
# 503 Documents Processed...16.55%
# 504 Documents Processed...16.58%
# 505 Documents Processed...16.61%
# 506 Documents Processed...16.64%
# 507 Documents Processed...16.68%
# 508 Documents Processed...16.71%
# 509 Documents Processed...16.74%
# 510 Documents Processed...16.78%
# 511 Documents Processed...16.81%
# 512 Documents Processed...16.84%
# 513 Documents Processed...16.88%
# 514 Documents Processed...16.91%
# 515 Documents Processed...16.94%
# 516 Documents Processed...16.97%
# 517 Documents Processed...17.01%
# 518 Documents Processed...17.04%
# 519 Documents Processed...17.07%
# 520 Documents Processed...17.11%
# 521 Documents Processed...17.14%
# 522 Documents Processed...17.17%
# 523 Documents Processed...17.2%
# 524 Documents Processed...17.24%
# 525 Documents Processed...17.27%
# 526 Documents Processed...17.3%
# 527 Documents Processed...17.34%
# 528 Documents Processed...17.37%
# 529 Documents Processed...17.4%
# 530 Documents Processed...17.43%
# 531 Documents Processed...17.47%
# 532 Documents Processed...17.5%
# 533 Documents Processed...17.53%
# 534 Documents Processed...17.57%
# 535 Documents Processed...17.6%
# 536 Documents Processed...17.63%
# 537 Documents Processed...17.66%
# 538 Documents Processed...17.7%
# 539 Documents Processed...17.73%
# 540 Documents Processed...17.76%
# 541 Documents Processed...17.8%
# 542 Documents Processed...17.83%
# 543 Documents Processed...17.86%
# 544 Documents Processed...17.89%
# 545 Documents Processed...17.93%
# 546 Documents Processed...17.96%
# 547 Documents Processed...17.99%
# 548 Documents Processed...18.03%
# 549 Documents Processed...18.06%
# 550 Documents Processed...18.09%
# 551 Documents Processed...18.12%
# 552 Documents Processed...18.16%
# 553 Documents Processed...18.19%
# 554 Documents Processed...18.22%
# 555 Documents Processed...18.26%
# 556 Documents Processed...18.29%
# 557 Documents Processed...18.32%
# 558 Documents Processed...18.36%
# 559 Documents Processed...18.39%
# 560 Documents Processed...18.42%
# 561 Documents Processed...18.45%
# 562 Documents Processed...18.49%
# 563 Documents Processed...18.52%
# 564 Documents Processed...18.55%
# 565 Documents Processed...18.59%
# 566 Documents Processed...18.62%
# 567 Documents Processed...18.65%
# 568 Documents Processed...18.68%
# 569 Documents Processed...18.72%
# 570 Documents Processed...18.75%
# 571 Documents Processed...18.78%
# 572 Documents Processed...18.82%
# 573 Documents Processed...18.85%
# 574 Documents Processed...18.88%
# 575 Documents Processed...18.91%
# 576 Documents Processed...18.95%
# 577 Documents Processed...18.98%
# 578 Documents Processed...19.01%
# 579 Documents Processed...19.05%
# 580 Documents Processed...19.08%
# 581 Documents Processed...19.11%
# 582 Documents Processed...19.14%
# 583 Documents Processed...19.18%
# 584 Documents Processed...19.21%
# 585 Documents Processed...19.24%
# 586 Documents Processed...19.28%
# 587 Documents Processed...19.31%
# 588 Documents Processed...19.34%
# 589 Documents Processed...19.38%
# 590 Documents Processed...19.41%
# 591 Documents Processed...19.44%
# 592 Documents Processed...19.47%
# 593 Documents Processed...19.51%
# 594 Documents Processed...19.54%
# 595 Documents Processed...19.57%
# 596 Documents Processed...19.61%
# 597 Documents Processed...19.64%
# 598 Documents Processed...19.67%
# 599 Documents Processed...19.7%
# 600 Documents Processed...19.74%
# 601 Documents Processed...19.77%
# 602 Documents Processed...19.8%
# 603 Documents Processed...19.84%
# 604 Documents Processed...19.87%
# 605 Documents Processed...19.9%
# 606 Documents Processed...19.93%
# 607 Documents Processed...19.97%
# 608 Documents Processed...20.0%
# 609 Documents Processed...20.03%
# 610 Documents Processed...20.07%
# 611 Documents Processed...20.1%
# 612 Documents Processed...20.13%
# 613 Documents Processed...20.16%
# 614 Documents Processed...20.2%
# 615 Documents Processed...20.23%
# 616 Documents Processed...20.26%
# 617 Documents Processed...20.3%
# 618 Documents Processed...20.33%
# 619 Documents Processed...20.36%
# 620 Documents Processed...20.39%
# 621 Documents Processed...20.43%
# 622 Documents Processed...20.46%
# 623 Documents Processed...20.49%
# 624 Documents Processed...20.53%
# 625 Documents Processed...20.56%
# 626 Documents Processed...20.59%
# 627 Documents Processed...20.62%
# 628 Documents Processed...20.66%
# 629 Documents Processed...20.69%
# 630 Documents Processed...20.72%
# 631 Documents Processed...20.76%
# 632 Documents Processed...20.79%
# 633 Documents Processed...20.82%
# 634 Documents Processed...20.86%
# 635 Documents Processed...20.89%
# 636 Documents Processed...20.92%
# 637 Documents Processed...20.95%
# 638 Documents Processed...20.99%
# 639 Documents Processed...21.02%
# 640 Documents Processed...21.05%
# 641 Documents Processed...21.09%
# 642 Documents Processed...21.12%
# 643 Documents Processed...21.15%
# 644 Documents Processed...21.18%
# 645 Documents Processed...21.22%
# 646 Documents Processed...21.25%
# 647 Documents Processed...21.28%
# 648 Documents Processed...21.32%
# 649 Documents Processed...21.35%
# 650 Documents Processed...21.38%
# 651 Documents Processed...21.41%
# 652 Documents Processed...21.45%
# 653 Documents Processed...21.48%
# 654 Documents Processed...21.51%
# 655 Documents Processed...21.55%
# 656 Documents Processed...21.58%
# 657 Documents Processed...21.61%
# 658 Documents Processed...21.64%
# 659 Documents Processed...21.68%
# 660 Documents Processed...21.71%
# 661 Documents Processed...21.74%
# 662 Documents Processed...21.78%
# 663 Documents Processed...21.81%
# 664 Documents Processed...21.84%
# 665 Documents Processed...21.88%
# 666 Documents Processed...21.91%
# 667 Documents Processed...21.94%
# 668 Documents Processed...21.97%
# 669 Documents Processed...22.01%
# 670 Documents Processed...22.04%
# 671 Documents Processed...22.07%
# 672 Documents Processed...22.11%
# 673 Documents Processed...22.14%
# 674 Documents Processed...22.17%
# 675 Documents Processed...22.2%
# 676 Documents Processed...22.24%
# 677 Documents Processed...22.27%
# 678 Documents Processed...22.3%
# 679 Documents Processed...22.34%
# 680 Documents Processed...22.37%
# 681 Documents Processed...22.4%
# 682 Documents Processed...22.43%
# 683 Documents Processed...22.47%
# 684 Documents Processed...22.5%
# 685 Documents Processed...22.53%
# 686 Documents Processed...22.57%
# 687 Documents Processed...22.6%
# 688 Documents Processed...22.63%
# 689 Documents Processed...22.66%
# 690 Documents Processed...22.7%
# 691 Documents Processed...22.73%
# 692 Documents Processed...22.76%
# 693 Documents Processed...22.8%
# 694 Documents Processed...22.83%
# 695 Documents Processed...22.86%
# 696 Documents Processed...22.89%
# 697 Documents Processed...22.93%
# 698 Documents Processed...22.96%
# 699 Documents Processed...22.99%
# 700 Documents Processed...23.03%
# 701 Documents Processed...23.06%
# 702 Documents Processed...23.09%
# 703 Documents Processed...23.12%
# 704 Documents Processed...23.16%
# 705 Documents Processed...23.19%
# 706 Documents Processed...23.22%
# 707 Documents Processed...23.26%
# 708 Documents Processed...23.29%
# 709 Documents Processed...23.32%
# 710 Documents Processed...23.36%
# 711 Documents Processed...23.39%
# 712 Documents Processed...23.42%
# 713 Documents Processed...23.45%
# 714 Documents Processed...23.49%
# 715 Documents Processed...23.52%
# 716 Documents Processed...23.55%
# 717 Documents Processed...23.59%
# 718 Documents Processed...23.62%
# 719 Documents Processed...23.65%
# 720 Documents Processed...23.68%
# 721 Documents Processed...23.72%
# 722 Documents Processed...23.75%
# 723 Documents Processed...23.78%
# 724 Documents Processed...23.82%
# 725 Documents Processed...23.85%
# 726 Documents Processed...23.88%
# 727 Documents Processed...23.91%
# 728 Documents Processed...23.95%
# 729 Documents Processed...23.98%
# 730 Documents Processed...24.01%
# 731 Documents Processed...24.05%
# 732 Documents Processed...24.08%
# 733 Documents Processed...24.11%
# 734 Documents Processed...24.14%
# 735 Documents Processed...24.18%
# 736 Documents Processed...24.21%
# 737 Documents Processed...24.24%
# 738 Documents Processed...24.28%
# 739 Documents Processed...24.31%
# 740 Documents Processed...24.34%
# 741 Documents Processed...24.38%
# 742 Documents Processed...24.41%
# 743 Documents Processed...24.44%
# 744 Documents Processed...24.47%
# 745 Documents Processed...24.51%
# 746 Documents Processed...24.54%
# 747 Documents Processed...24.57%
# 748 Documents Processed...24.61%
# 749 Documents Processed...24.64%
# 750 Documents Processed...24.67%
# 751 Documents Processed...24.7%
# 752 Documents Processed...24.74%
# 753 Documents Processed...24.77%
# 754 Documents Processed...24.8%
# 755 Documents Processed...24.84%
# 756 Documents Processed...24.87%
# 757 Documents Processed...24.9%
# 758 Documents Processed...24.93%
# 759 Documents Processed...24.97%
# 760 Documents Processed...25.0%
# 761 Documents Processed...25.03%
# 762 Documents Processed...25.07%
# 763 Documents Processed...25.1%
# 764 Documents Processed...25.13%
# 765 Documents Processed...25.16%
# 766 Documents Processed...25.2%
# 767 Documents Processed...25.23%
# 768 Documents Processed...25.26%
# 769 Documents Processed...25.3%
# 770 Documents Processed...25.33%
# 771 Documents Processed...25.36%
# 772 Documents Processed...25.39%
# 773 Documents Processed...25.43%
# 774 Documents Processed...25.46%
# 775 Documents Processed...25.49%
# 776 Documents Processed...25.53%
# 777 Documents Processed...25.56%
# 778 Documents Processed...25.59%
# 779 Documents Processed...25.62%
# 780 Documents Processed...25.66%
# 781 Documents Processed...25.69%
# 782 Documents Processed...25.72%
# 783 Documents Processed...25.76%
# 784 Documents Processed...25.79%
# 785 Documents Processed...25.82%
# 786 Documents Processed...25.86%
# 787 Documents Processed...25.89%
# 788 Documents Processed...25.92%
# 789 Documents Processed...25.95%
# 790 Documents Processed...25.99%
# 791 Documents Processed...26.02%
# 792 Documents Processed...26.05%
# 793 Documents Processed...26.09%
# 794 Documents Processed...26.12%
# 795 Documents Processed...26.15%
# 796 Documents Processed...26.18%
# 797 Documents Processed...26.22%
# 798 Documents Processed...26.25%
# 799 Documents Processed...26.28%
# 800 Documents Processed...26.32%
# 801 Documents Processed...26.35%
# 802 Documents Processed...26.38%
# 803 Documents Processed...26.41%
# 804 Documents Processed...26.45%
# 805 Documents Processed...26.48%
# 806 Documents Processed...26.51%
# 807 Documents Processed...26.55%
# 808 Documents Processed...26.58%
# 809 Documents Processed...26.61%
# 810 Documents Processed...26.64%
# 811 Documents Processed...26.68%
# 812 Documents Processed...26.71%
# 813 Documents Processed...26.74%
# 814 Documents Processed...26.78%
# 815 Documents Processed...26.81%
# 816 Documents Processed...26.84%
# 817 Documents Processed...26.88%
# 818 Documents Processed...26.91%
# 819 Documents Processed...26.94%
# 820 Documents Processed...26.97%
# 821 Documents Processed...27.01%
# 822 Documents Processed...27.04%
# 823 Documents Processed...27.07%
# 824 Documents Processed...27.11%
# 825 Documents Processed...27.14%
# 826 Documents Processed...27.17%
# 827 Documents Processed...27.2%
# 828 Documents Processed...27.24%
# 829 Documents Processed...27.27%
# 830 Documents Processed...27.3%
# 831 Documents Processed...27.34%
# 832 Documents Processed...27.37%
# 833 Documents Processed...27.4%
# 834 Documents Processed...27.43%
# 835 Documents Processed...27.47%
# 836 Documents Processed...27.5%
# 837 Documents Processed...27.53%
# 838 Documents Processed...27.57%
# 839 Documents Processed...27.6%
# 840 Documents Processed...27.63%
# 841 Documents Processed...27.66%
# 842 Documents Processed...27.7%
# 843 Documents Processed...27.73%
# 844 Documents Processed...27.76%
# 845 Documents Processed...27.8%
# 846 Documents Processed...27.83%
# 847 Documents Processed...27.86%
# 848 Documents Processed...27.89%
# 849 Documents Processed...27.93%
# 850 Documents Processed...27.96%
# 851 Documents Processed...27.99%
# 852 Documents Processed...28.03%
# 853 Documents Processed...28.06%
# 854 Documents Processed...28.09%
# 855 Documents Processed...28.12%
# 856 Documents Processed...28.16%
# 857 Documents Processed...28.19%
# 858 Documents Processed...28.22%
# 859 Documents Processed...28.26%
# 860 Documents Processed...28.29%
# 861 Documents Processed...28.32%
# 862 Documents Processed...28.36%
# 863 Documents Processed...28.39%
# 864 Documents Processed...28.42%
# 865 Documents Processed...28.45%
# 866 Documents Processed...28.49%
# 867 Documents Processed...28.52%
# 868 Documents Processed...28.55%
# 869 Documents Processed...28.59%
# 870 Documents Processed...28.62%
# 871 Documents Processed...28.65%
# 872 Documents Processed...28.68%
# 873 Documents Processed...28.72%
# 874 Documents Processed...28.75%
# 875 Documents Processed...28.78%
# 876 Documents Processed...28.82%
# 877 Documents Processed...28.85%
# 878 Documents Processed...28.88%
# 879 Documents Processed...28.91%
# 880 Documents Processed...28.95%
# 881 Documents Processed...28.98%
# 882 Documents Processed...29.01%
# 883 Documents Processed...29.05%
# 884 Documents Processed...29.08%
# 885 Documents Processed...29.11%
# 886 Documents Processed...29.14%
# 887 Documents Processed...29.18%
# 888 Documents Processed...29.21%
# 889 Documents Processed...29.24%
# 890 Documents Processed...29.28%
# 891 Documents Processed...29.31%
# 892 Documents Processed...29.34%
# 893 Documents Processed...29.38%
# 894 Documents Processed...29.41%
# 895 Documents Processed...29.44%
# 896 Documents Processed...29.47%
# 897 Documents Processed...29.51%
# 898 Documents Processed...29.54%
# 899 Documents Processed...29.57%
# 900 Documents Processed...29.61%
# 901 Documents Processed...29.64%
# 902 Documents Processed...29.67%
# 903 Documents Processed...29.7%
# 904 Documents Processed...29.74%
# 905 Documents Processed...29.77%
# 906 Documents Processed...29.8%
# 907 Documents Processed...29.84%
# 908 Documents Processed...29.87%
# 909 Documents Processed...29.9%
# 910 Documents Processed...29.93%
# 911 Documents Processed...29.97%
# 912 Documents Processed...30.0%
# 913 Documents Processed...30.03%
# 914 Documents Processed...30.07%
# 915 Documents Processed...30.1%
# 916 Documents Processed...30.13%
# 917 Documents Processed...30.16%
# 918 Documents Processed...30.2%
# 919 Documents Processed...30.23%
# 920 Documents Processed...30.26%
# 921 Documents Processed...30.3%
# 922 Documents Processed...30.33%
# 923 Documents Processed...30.36%
# 924 Documents Processed...30.39%
# 925 Documents Processed...30.43%
# 926 Documents Processed...30.46%
# 927 Documents Processed...30.49%
# 928 Documents Processed...30.53%
# 929 Documents Processed...30.56%
# 930 Documents Processed...30.59%
# 931 Documents Processed...30.63%
# 932 Documents Processed...30.66%
# 933 Documents Processed...30.69%
# 934 Documents Processed...30.72%
# 935 Documents Processed...30.76%
# 936 Documents Processed...30.79%
# 937 Documents Processed...30.82%
# 938 Documents Processed...30.86%
# 939 Documents Processed...30.89%
# 940 Documents Processed...30.92%
# 941 Documents Processed...30.95%
# 942 Documents Processed...30.99%
# 943 Documents Processed...31.02%
# 944 Documents Processed...31.05%
# 945 Documents Processed...31.09%
# 946 Documents Processed...31.12%
# 947 Documents Processed...31.15%
# 948 Documents Processed...31.18%
# 949 Documents Processed...31.22%
# 950 Documents Processed...31.25%
# 951 Documents Processed...31.28%
# 952 Documents Processed...31.32%
# 953 Documents Processed...31.35%
# 954 Documents Processed...31.38%
# 955 Documents Processed...31.41%
# 956 Documents Processed...31.45%
# 957 Documents Processed...31.48%
# 958 Documents Processed...31.51%
# 959 Documents Processed...31.55%
# 960 Documents Processed...31.58%
# 961 Documents Processed...31.61%
# 962 Documents Processed...31.64%
# 963 Documents Processed...31.68%
# 964 Documents Processed...31.71%
# 965 Documents Processed...31.74%
# 966 Documents Processed...31.78%
# 967 Documents Processed...31.81%
# 968 Documents Processed...31.84%
# 969 Documents Processed...31.87%
# 970 Documents Processed...31.91%
# 971 Documents Processed...31.94%
# 972 Documents Processed...31.97%
# 973 Documents Processed...32.01%
# 974 Documents Processed...32.04%
# 975 Documents Processed...32.07%
# 976 Documents Processed...32.11%
# 977 Documents Processed...32.14%
# 978 Documents Processed...32.17%
# 979 Documents Processed...32.2%
# 980 Documents Processed...32.24%
# 981 Documents Processed...32.27%
# 982 Documents Processed...32.3%
# 983 Documents Processed...32.34%
# 984 Documents Processed...32.37%
# 985 Documents Processed...32.4%
# 986 Documents Processed...32.43%
# 987 Documents Processed...32.47%
# 988 Documents Processed...32.5%
# 989 Documents Processed...32.53%
# 990 Documents Processed...32.57%
# 991 Documents Processed...32.6%
# 992 Documents Processed...32.63%
# 993 Documents Processed...32.66%
# 994 Documents Processed...32.7%
# 995 Documents Processed...32.73%
# 996 Documents Processed...32.76%
# 997 Documents Processed...32.8%
# 998 Documents Processed...32.83%
# 999 Documents Processed...32.86%
# 1000 Documents Processed...32.89%
# 1001 Documents Processed...32.93%
# 1002 Documents Processed...32.96%
# 1003 Documents Processed...32.99%
# 1004 Documents Processed...33.03%
# 1005 Documents Processed...33.06%
# 1006 Documents Processed...33.09%
# 1007 Documents Processed...33.12%
# 1008 Documents Processed...33.16%
# 1009 Documents Processed...33.19%
# 1010 Documents Processed...33.22%
# 1011 Documents Processed...33.26%
# 1012 Documents Processed...33.29%
# 1013 Documents Processed...33.32%
# 1014 Documents Processed...33.36%
# 1015 Documents Processed...33.39%
# 1016 Documents Processed...33.42%
# 1017 Documents Processed...33.45%
# 1018 Documents Processed...33.49%
# 1019 Documents Processed...33.52%
# 1020 Documents Processed...33.55%
# 1021 Documents Processed...33.59%
# 1022 Documents Processed...33.62%
# 1023 Documents Processed...33.65%
# 1024 Documents Processed...33.68%
# 1025 Documents Processed...33.72%
# 1026 Documents Processed...33.75%
# 1027 Documents Processed...33.78%
# 1028 Documents Processed...33.82%
# 1029 Documents Processed...33.85%
# 1030 Documents Processed...33.88%
# 1031 Documents Processed...33.91%
# 1032 Documents Processed...33.95%
# 1033 Documents Processed...33.98%
# 1034 Documents Processed...34.01%
# 1035 Documents Processed...34.05%
# 1036 Documents Processed...34.08%
# 1037 Documents Processed...34.11%
# 1038 Documents Processed...34.14%
# 1039 Documents Processed...34.18%
# 1040 Documents Processed...34.21%
# 1041 Documents Processed...34.24%
# 1042 Documents Processed...34.28%
# 1043 Documents Processed...34.31%
# 1044 Documents Processed...34.34%
# 1045 Documents Processed...34.38%
# 1046 Documents Processed...34.41%
# 1047 Documents Processed...34.44%
# 1048 Documents Processed...34.47%
# 1049 Documents Processed...34.51%
# 1050 Documents Processed...34.54%
# 1051 Documents Processed...34.57%
# 1052 Documents Processed...34.61%
# 1053 Documents Processed...34.64%
# 1054 Documents Processed...34.67%
# 1055 Documents Processed...34.7%
# 1056 Documents Processed...34.74%
# 1057 Documents Processed...34.77%
# 1058 Documents Processed...34.8%
# 1059 Documents Processed...34.84%
# 1060 Documents Processed...34.87%
# 1061 Documents Processed...34.9%
# 1062 Documents Processed...34.93%
# 1063 Documents Processed...34.97%
# 1064 Documents Processed...35.0%
# 1065 Documents Processed...35.03%
# 1066 Documents Processed...35.07%
# 1067 Documents Processed...35.1%
# 1068 Documents Processed...35.13%
# 1069 Documents Processed...35.16%
# 1070 Documents Processed...35.2%
# 1071 Documents Processed...35.23%
# 1072 Documents Processed...35.26%
# 1073 Documents Processed...35.3%
# 1074 Documents Processed...35.33%
# 1075 Documents Processed...35.36%
# 1076 Documents Processed...35.39%
# 1077 Documents Processed...35.43%
# 1078 Documents Processed...35.46%
# 1079 Documents Processed...35.49%
# 1080 Documents Processed...35.53%
# 1081 Documents Processed...35.56%
# 1082 Documents Processed...35.59%
# 1083 Documents Processed...35.62%
# 1084 Documents Processed...35.66%
# 1085 Documents Processed...35.69%
# 1086 Documents Processed...35.72%
# 1087 Documents Processed...35.76%
# 1088 Documents Processed...35.79%
# 1089 Documents Processed...35.82%
# 1090 Documents Processed...35.86%
# 1091 Documents Processed...35.89%
# 1092 Documents Processed...35.92%
# 1093 Documents Processed...35.95%
# 1094 Documents Processed...35.99%
# 1095 Documents Processed...36.02%
# 1096 Documents Processed...36.05%
# 1097 Documents Processed...36.09%
# 1098 Documents Processed...36.12%
# 1099 Documents Processed...36.15%
# 1100 Documents Processed...36.18%
# 1101 Documents Processed...36.22%
# 1102 Documents Processed...36.25%
# 1103 Documents Processed...36.28%
# 1104 Documents Processed...36.32%
# 1105 Documents Processed...36.35%
# 1106 Documents Processed...36.38%
# 1107 Documents Processed...36.41%
# 1108 Documents Processed...36.45%
# 1109 Documents Processed...36.48%
# 1110 Documents Processed...36.51%
# 1111 Documents Processed...36.55%
# 1112 Documents Processed...36.58%
# 1113 Documents Processed...36.61%
# 1114 Documents Processed...36.64%
# 1115 Documents Processed...36.68%
# 1116 Documents Processed...36.71%
# 1117 Documents Processed...36.74%
# 1118 Documents Processed...36.78%
# 1119 Documents Processed...36.81%
# 1120 Documents Processed...36.84%
# 1121 Documents Processed...36.88%
# 1122 Documents Processed...36.91%
# 1123 Documents Processed...36.94%
# 1124 Documents Processed...36.97%
# 1125 Documents Processed...37.01%
# 1126 Documents Processed...37.04%
# 1127 Documents Processed...37.07%
# 1128 Documents Processed...37.11%
# 1129 Documents Processed...37.14%
# 1130 Documents Processed...37.17%
# 1131 Documents Processed...37.2%
# 1132 Documents Processed...37.24%
# 1133 Documents Processed...37.27%
# 1134 Documents Processed...37.3%
# 1135 Documents Processed...37.34%
# 1136 Documents Processed...37.37%
# 1137 Documents Processed...37.4%
# 1138 Documents Processed...37.43%
# 1139 Documents Processed...37.47%
# 1140 Documents Processed...37.5%
# 1141 Documents Processed...37.53%
# 1142 Documents Processed...37.57%
# 1143 Documents Processed...37.6%
# 1144 Documents Processed...37.63%
# 1145 Documents Processed...37.66%
# 1146 Documents Processed...37.7%
# 1147 Documents Processed...37.73%
# 1148 Documents Processed...37.76%
# 1149 Documents Processed...37.8%
# 1150 Documents Processed...37.83%
# 1151 Documents Processed...37.86%
# 1152 Documents Processed...37.89%
# 1153 Documents Processed...37.93%
# 1154 Documents Processed...37.96%
# 1155 Documents Processed...37.99%
# 1156 Documents Processed...38.03%
# 1157 Documents Processed...38.06%
# 1158 Documents Processed...38.09%
# 1159 Documents Processed...38.12%
# 1160 Documents Processed...38.16%
# 1161 Documents Processed...38.19%
# 1162 Documents Processed...38.22%
# 1163 Documents Processed...38.26%
# 1164 Documents Processed...38.29%
# 1165 Documents Processed...38.32%
# 1166 Documents Processed...38.36%
# 1167 Documents Processed...38.39%
# 1168 Documents Processed...38.42%
# 1169 Documents Processed...38.45%
# 1170 Documents Processed...38.49%
# 1171 Documents Processed...38.52%
# 1172 Documents Processed...38.55%
# 1173 Documents Processed...38.59%
# 1174 Documents Processed...38.62%
# 1175 Documents Processed...38.65%
# 1176 Documents Processed...38.68%
# 1177 Documents Processed...38.72%
# 1178 Documents Processed...38.75%
# 1179 Documents Processed...38.78%
# 1180 Documents Processed...38.82%
# 1181 Documents Processed...38.85%
# 1182 Documents Processed...38.88%
# 1183 Documents Processed...38.91%
# 1184 Documents Processed...38.95%
# 1185 Documents Processed...38.98%
# 1186 Documents Processed...39.01%
# 1187 Documents Processed...39.05%
# 1188 Documents Processed...39.08%
# 1189 Documents Processed...39.11%
# 1190 Documents Processed...39.14%
# 1191 Documents Processed...39.18%
# 1192 Documents Processed...39.21%
# 1193 Documents Processed...39.24%
# 1194 Documents Processed...39.28%
# 1195 Documents Processed...39.31%
# 1196 Documents Processed...39.34%
# 1197 Documents Processed...39.38%
# 1198 Documents Processed...39.41%
# 1199 Documents Processed...39.44%
# 1200 Documents Processed...39.47%
# 1201 Documents Processed...39.51%
# 1202 Documents Processed...39.54%
# 1203 Documents Processed...39.57%
# 1204 Documents Processed...39.61%
# 1205 Documents Processed...39.64%
# 1206 Documents Processed...39.67%
# 1207 Documents Processed...39.7%
# 1208 Documents Processed...39.74%
# 1209 Documents Processed...39.77%
# 1210 Documents Processed...39.8%
# 1211 Documents Processed...39.84%
# 1212 Documents Processed...39.87%
# 1213 Documents Processed...39.9%
# 1214 Documents Processed...39.93%
# 1215 Documents Processed...39.97%
# 1216 Documents Processed...40.0%
# 1217 Documents Processed...40.03%
# 1218 Documents Processed...40.07%
# 1219 Documents Processed...40.1%
# 1220 Documents Processed...40.13%
# 1221 Documents Processed...40.16%
# 1222 Documents Processed...40.2%
# 1223 Documents Processed...40.23%
# 1224 Documents Processed...40.26%
# 1225 Documents Processed...40.3%
# 1226 Documents Processed...40.33%
# 1227 Documents Processed...40.36%
# 1228 Documents Processed...40.39%
# 1229 Documents Processed...40.43%
# 1230 Documents Processed...40.46%
# 1231 Documents Processed...40.49%
# 1232 Documents Processed...40.53%
# 1233 Documents Processed...40.56%
# 1234 Documents Processed...40.59%
# 1235 Documents Processed...40.62%
# 1236 Documents Processed...40.66%
# 1237 Documents Processed...40.69%
# 1238 Documents Processed...40.72%
# 1239 Documents Processed...40.76%
# 1240 Documents Processed...40.79%
# 1241 Documents Processed...40.82%
# 1242 Documents Processed...40.86%
# 1243 Documents Processed...40.89%
# 1244 Documents Processed...40.92%
# 1245 Documents Processed...40.95%
# 1246 Documents Processed...40.99%
# 1247 Documents Processed...41.02%
# 1248 Documents Processed...41.05%
# 1249 Documents Processed...41.09%
# 1250 Documents Processed...41.12%
# 1251 Documents Processed...41.15%
# 1252 Documents Processed...41.18%
# 1253 Documents Processed...41.22%
# 1254 Documents Processed...41.25%
# 1255 Documents Processed...41.28%
# 1256 Documents Processed...41.32%
# 1257 Documents Processed...41.35%
# 1258 Documents Processed...41.38%
# 1259 Documents Processed...41.41%
# 1260 Documents Processed...41.45%
# 1261 Documents Processed...41.48%
# 1262 Documents Processed...41.51%
# 1263 Documents Processed...41.55%
# 1264 Documents Processed...41.58%
# 1265 Documents Processed...41.61%
# 1266 Documents Processed...41.64%
# 1267 Documents Processed...41.68%
# 1268 Documents Processed...41.71%
# 1269 Documents Processed...41.74%
# 1270 Documents Processed...41.78%
# 1271 Documents Processed...41.81%
# 1272 Documents Processed...41.84%
# 1273 Documents Processed...41.88%
# 1274 Documents Processed...41.91%
# 1275 Documents Processed...41.94%
# 1276 Documents Processed...41.97%
# 1277 Documents Processed...42.01%
# 1278 Documents Processed...42.04%
# 1279 Documents Processed...42.07%
# 1280 Documents Processed...42.11%
# 1281 Documents Processed...42.14%
# 1282 Documents Processed...42.17%
# 1283 Documents Processed...42.2%
# 1284 Documents Processed...42.24%
# 1285 Documents Processed...42.27%
# 1286 Documents Processed...42.3%
# 1287 Documents Processed...42.34%
# 1288 Documents Processed...42.37%
# 1289 Documents Processed...42.4%
# 1290 Documents Processed...42.43%
# 1291 Documents Processed...42.47%
# 1292 Documents Processed...42.5%
# 1293 Documents Processed...42.53%
# 1294 Documents Processed...42.57%
# 1295 Documents Processed...42.6%
# 1296 Documents Processed...42.63%
# 1297 Documents Processed...42.66%
# 1298 Documents Processed...42.7%
# 1299 Documents Processed...42.73%
# 1300 Documents Processed...42.76%
# 1301 Documents Processed...42.8%
# 1302 Documents Processed...42.83%
# 1303 Documents Processed...42.86%
# 1304 Documents Processed...42.89%
# 1305 Documents Processed...42.93%
# 1306 Documents Processed...42.96%
# 1307 Documents Processed...42.99%
# 1308 Documents Processed...43.03%
# 1309 Documents Processed...43.06%
# 1310 Documents Processed...43.09%
# 1311 Documents Processed...43.12%
# 1312 Documents Processed...43.16%
# 1313 Documents Processed...43.19%
# 1314 Documents Processed...43.22%
# 1315 Documents Processed...43.26%
# 1316 Documents Processed...43.29%
# 1317 Documents Processed...43.32%
# 1318 Documents Processed...43.36%
# 1319 Documents Processed...43.39%
# 1320 Documents Processed...43.42%
# 1321 Documents Processed...43.45%
# 1322 Documents Processed...43.49%
# 1323 Documents Processed...43.52%
# 1324 Documents Processed...43.55%
# 1325 Documents Processed...43.59%
# 1326 Documents Processed...43.62%
# 1327 Documents Processed...43.65%
# 1328 Documents Processed...43.68%
# 1329 Documents Processed...43.72%
# 1330 Documents Processed...43.75%
# 1331 Documents Processed...43.78%
# 1332 Documents Processed...43.82%
# 1333 Documents Processed...43.85%
# 1334 Documents Processed...43.88%
# 1335 Documents Processed...43.91%
# 1336 Documents Processed...43.95%
# 1337 Documents Processed...43.98%
# 1338 Documents Processed...44.01%
# 1339 Documents Processed...44.05%
# 1340 Documents Processed...44.08%
# 1341 Documents Processed...44.11%
# 1342 Documents Processed...44.14%
# 1343 Documents Processed...44.18%
# 1344 Documents Processed...44.21%
# 1345 Documents Processed...44.24%
# 1346 Documents Processed...44.28%
# 1347 Documents Processed...44.31%
# 1348 Documents Processed...44.34%
# 1349 Documents Processed...44.38%
# 1350 Documents Processed...44.41%
# 1351 Documents Processed...44.44%
# 1352 Documents Processed...44.47%
# 1353 Documents Processed...44.51%
# 1354 Documents Processed...44.54%
# 1355 Documents Processed...44.57%
# 1356 Documents Processed...44.61%
# 1357 Documents Processed...44.64%
# 1358 Documents Processed...44.67%
# 1359 Documents Processed...44.7%
# 1360 Documents Processed...44.74%
# 1361 Documents Processed...44.77%
# 1362 Documents Processed...44.8%
# 1363 Documents Processed...44.84%
# 1364 Documents Processed...44.87%
# 1365 Documents Processed...44.9%
# 1366 Documents Processed...44.93%
# 1367 Documents Processed...44.97%
# 1368 Documents Processed...45.0%
# 1369 Documents Processed...45.03%
# 1370 Documents Processed...45.07%
# 1371 Documents Processed...45.1%
# 1372 Documents Processed...45.13%
# 1373 Documents Processed...45.16%
# 1374 Documents Processed...45.2%
# 1375 Documents Processed...45.23%
# 1376 Documents Processed...45.26%
# 1377 Documents Processed...45.3%
# 1378 Documents Processed...45.33%
# 1379 Documents Processed...45.36%
# 1380 Documents Processed...45.39%
# 1381 Documents Processed...45.43%
# 1382 Documents Processed...45.46%
# 1383 Documents Processed...45.49%
# 1384 Documents Processed...45.53%
# 1385 Documents Processed...45.56%
# 1386 Documents Processed...45.59%
# 1387 Documents Processed...45.62%
# 1388 Documents Processed...45.66%
# 1389 Documents Processed...45.69%
# 1390 Documents Processed...45.72%
# 1391 Documents Processed...45.76%
# 1392 Documents Processed...45.79%
# 1393 Documents Processed...45.82%
# 1394 Documents Processed...45.86%
# 1395 Documents Processed...45.89%
# 1396 Documents Processed...45.92%
# 1397 Documents Processed...45.95%
# 1398 Documents Processed...45.99%
# 1399 Documents Processed...46.02%
# 1400 Documents Processed...46.05%
# 1401 Documents Processed...46.09%
# 1402 Documents Processed...46.12%
# 1403 Documents Processed...46.15%
# 1404 Documents Processed...46.18%
# 1405 Documents Processed...46.22%
# 1406 Documents Processed...46.25%
# 1407 Documents Processed...46.28%
# 1408 Documents Processed...46.32%
# 1409 Documents Processed...46.35%
# 1410 Documents Processed...46.38%
# 1411 Documents Processed...46.41%
# 1412 Documents Processed...46.45%
# 1413 Documents Processed...46.48%
# 1414 Documents Processed...46.51%
# 1415 Documents Processed...46.55%
# 1416 Documents Processed...46.58%
# 1417 Documents Processed...46.61%
# 1418 Documents Processed...46.64%
# 1419 Documents Processed...46.68%
# 1420 Documents Processed...46.71%
# 1421 Documents Processed...46.74%
# 1422 Documents Processed...46.78%
# 1423 Documents Processed...46.81%
# 1424 Documents Processed...46.84%
# 1425 Documents Processed...46.88%
# 1426 Documents Processed...46.91%
# 1427 Documents Processed...46.94%
# 1428 Documents Processed...46.97%
# 1429 Documents Processed...47.01%
# 1430 Documents Processed...47.04%
# 1431 Documents Processed...47.07%
# 1432 Documents Processed...47.11%
# 1433 Documents Processed...47.14%
# 1434 Documents Processed...47.17%
# 1435 Documents Processed...47.2%
# 1436 Documents Processed...47.24%
# 1437 Documents Processed...47.27%
# 1438 Documents Processed...47.3%
# 1439 Documents Processed...47.34%
# 1440 Documents Processed...47.37%
# 1441 Documents Processed...47.4%
# 1442 Documents Processed...47.43%
# 1443 Documents Processed...47.47%
# 1444 Documents Processed...47.5%
# 1445 Documents Processed...47.53%
# 1446 Documents Processed...47.57%
# 1447 Documents Processed...47.6%
# 1448 Documents Processed...47.63%
# 1449 Documents Processed...47.66%
# 1450 Documents Processed...47.7%
# 1451 Documents Processed...47.73%
# ...
# 2570 Documents Processed...84.54%
# 2571 Documents Processed...84.57%
# 2572 Documents Processed...84.61%
# 2573 Documents Processed...84.64%
# 2574 Documents Processed...84.67%
# 2575 Documents Processed...84.7%
# 2576 Documents Processed...84.74%
# 2577 Documents Processed...84.77%
# 2578 Documents Processed...84.8%
# 2579 Documents Processed...84.84%
# 2580 Documents Processed...84.87%
# 2581 Documents Processed...84.9%
# 2582 Documents Processed...84.93%
# 2583 Documents Processed...84.97%
# 2584 Documents Processed...85.0%
# 2585 Documents Processed...85.03%
# 2586 Documents Processed...85.07%
# 2587 Documents Processed...85.1%
# 2588 Documents Processed...85.13%
# 2589 Documents Processed...85.16%
# 2590 Documents Processed...85.2%
# 2591 Documents Processed...85.23%
# 2592 Documents Processed...85.26%
# 2593 Documents Processed...85.3%
# 2594 Documents Processed...85.33%
# 2595 Documents Processed...85.36%
# 2596 Documents Processed...85.39%
# 2597 Documents Processed...85.43%
# 2598 Documents Processed...85.46%
# 2599 Documents Processed...85.49%
# 2600 Documents Processed...85.53%
# 2601 Documents Processed...85.56%
# 2602 Documents Processed...85.59%
# 2603 Documents Processed...85.62%
# 2604 Documents Processed...85.66%
# 2605 Documents Processed...85.69%
# 2606 Documents Processed...85.72%
# 2607 Documents Processed...85.76%
# 2608 Documents Processed...85.79%
# 2609 Documents Processed...85.82%
# 2610 Documents Processed...85.86%
# 2611 Documents Processed...85.89%
# 2612 Documents Processed...85.92%
# 2613 Documents Processed...85.95%
# 2614 Documents Processed...85.99%
# 2615 Documents Processed...86.02%
# 2616 Documents Processed...86.05%
# 2617 Documents Processed...86.09%
# 2618 Documents Processed...86.12%
# 2619 Documents Processed...86.15%
# 2620 Documents Processed...86.18%
# 2621 Documents Processed...86.22%
# 2622 Documents Processed...86.25%
# 2623 Documents Processed...86.28%
# 2624 Documents Processed...86.32%
# 2625 Documents Processed...86.35%
# 2626 Documents Processed...86.38%
# 2627 Documents Processed...86.41%
# 2628 Documents Processed...86.45%
# 2629 Documents Processed...86.48%
# 2630 Documents Processed...86.51%
# 2631 Documents Processed...86.55%
# 2632 Documents Processed...86.58%
# 2633 Documents Processed...86.61%
# 2634 Documents Processed...86.64%
# 2635 Documents Processed...86.68%
# 2636 Documents Processed...86.71%
# 2637 Documents Processed...86.74%
# 2638 Documents Processed...86.78%
# 2639 Documents Processed...86.81%
# 2640 Documents Processed...86.84%
# 2641 Documents Processed...86.88%
# 2642 Documents Processed...86.91%
# 2643 Documents Processed...86.94%
# 2644 Documents Processed...86.97%
# 2645 Documents Processed...87.01%
# 2646 Documents Processed...87.04%
# 2647 Documents Processed...87.07%
# 2648 Documents Processed...87.11%
# 2649 Documents Processed...87.14%
# 2650 Documents Processed...87.17%
# 2651 Documents Processed...87.2%
# 2652 Documents Processed...87.24%
# 2653 Documents Processed...87.27%
# 2654 Documents Processed...87.3%
# 2655 Documents Processed...87.34%
# 2656 Documents Processed...87.37%
# 2657 Documents Processed...87.4%
# 2658 Documents Processed...87.43%
# 2659 Documents Processed...87.47%
# 2660 Documents Processed...87.5%
# 2661 Documents Processed...87.53%
# 2662 Documents Processed...87.57%
# 2663 Documents Processed...87.6%
# 2664 Documents Processed...87.63%
# 2665 Documents Processed...87.66%
# 2666 Documents Processed...87.7%
# 2667 Documents Processed...87.73%
# 2668 Documents Processed...87.76%
# 2669 Documents Processed...87.8%
# 2670 Documents Processed...87.83%
# 2671 Documents Processed...87.86%
# 2672 Documents Processed...87.89%
# 2673 Documents Processed...87.93%
# 2674 Documents Processed...87.96%
# 2675 Documents Processed...87.99%
# 2676 Documents Processed...88.03%
# 2677 Documents Processed...88.06%
# 2678 Documents Processed...88.09%
# 2679 Documents Processed...88.12%
# 2680 Documents Processed...88.16%
# 2681 Documents Processed...88.19%
# 2682 Documents Processed...88.22%
# 2683 Documents Processed...88.26%
# 2684 Documents Processed...88.29%
# 2685 Documents Processed...88.32%
# 2686 Documents Processed...88.36%
# 2687 Documents Processed...88.39%
# 2688 Documents Processed...88.42%
# 2689 Documents Processed...88.45%
# 2690 Documents Processed...88.49%
# 2691 Documents Processed...88.52%
# 2692 Documents Processed...88.55%
# 2693 Documents Processed...88.59%
# 2694 Documents Processed...88.62%
# 2695 Documents Processed...88.65%
# 2696 Documents Processed...88.68%
# 2697 Documents Processed...88.72%
# 2698 Documents Processed...88.75%
# 2699 Documents Processed...88.78%
# 2700 Documents Processed...88.82%
# 2701 Documents Processed...88.85%
# 2702 Documents Processed...88.88%
# 2703 Documents Processed...88.91%
# 2704 Documents Processed...88.95%
# 2705 Documents Processed...88.98%
# 2706 Documents Processed...89.01%
# 2707 Documents Processed...89.05%
# 2708 Documents Processed...89.08%
# 2709 Documents Processed...89.11%
# 2710 Documents Processed...89.14%
# 2711 Documents Processed...89.18%
# 2712 Documents Processed...89.21%
# 2713 Documents Processed...89.24%
# 2714 Documents Processed...89.28%
# 2715 Documents Processed...89.31%
# 2716 Documents Processed...89.34%
# 2717 Documents Processed...89.38%
# 2718 Documents Processed...89.41%
# 2719 Documents Processed...89.44%
# 2720 Documents Processed...89.47%
# 2721 Documents Processed...89.51%
# 2722 Documents Processed...89.54%
# 2723 Documents Processed...89.57%
# 2724 Documents Processed...89.61%
# 2725 Documents Processed...89.64%
# 2726 Documents Processed...89.67%
# 2727 Documents Processed...89.7%
# 2728 Documents Processed...89.74%
# 2729 Documents Processed...89.77%
# 2730 Documents Processed...89.8%
# 2731 Documents Processed...89.84%
# 2732 Documents Processed...89.87%
# 2733 Documents Processed...89.9%
# 2734 Documents Processed...89.93%
# 2735 Documents Processed...89.97%
# 2736 Documents Processed...90.0%
# 2737 Documents Processed...90.03%
# 2738 Documents Processed...90.07%
# 2739 Documents Processed...90.1%
# 2740 Documents Processed...90.13%
# 2741 Documents Processed...90.16%
# 2742 Documents Processed...90.2%
# 2743 Documents Processed...90.23%
# 2744 Documents Processed...90.26%
# 2745 Documents Processed...90.3%
# 2746 Documents Processed...90.33%
# 2747 Documents Processed...90.36%
# 2748 Documents Processed...90.39%
# 2749 Documents Processed...90.43%
# 2750 Documents Processed...90.46%
# 2751 Documents Processed...90.49%
# 2752 Documents Processed...90.53%
# 2753 Documents Processed...90.56%
# 2754 Documents Processed...90.59%
# 2755 Documents Processed...90.62%
# 2756 Documents Processed...90.66%
# 2757 Documents Processed...90.69%
# 2758 Documents Processed...90.72%
# 2759 Documents Processed...90.76%
# 2760 Documents Processed...90.79%
# 2761 Documents Processed...90.82%
# 2762 Documents Processed...90.86%
# 2763 Documents Processed...90.89%
# 2764 Documents Processed...90.92%
# 2765 Documents Processed...90.95%
# 2766 Documents Processed...90.99%
# 2767 Documents Processed...91.02%
# 2768 Documents Processed...91.05%
# 2769 Documents Processed...91.09%
# 2770 Documents Processed...91.12%
# 2771 Documents Processed...91.15%
# 2772 Documents Processed...91.18%
# 2773 Documents Processed...91.22%
# 2774 Documents Processed...91.25%
# 2775 Documents Processed...91.28%
# 2776 Documents Processed...91.32%
# 2777 Documents Processed...91.35%
# 2778 Documents Processed...91.38%
# 2779 Documents Processed...91.41%
# 2780 Documents Processed...91.45%
# 2781 Documents Processed...91.48%
# 2782 Documents Processed...91.51%
# 2783 Documents Processed...91.55%
# 2784 Documents Processed...91.58%
# 2785 Documents Processed...91.61%
# 2786 Documents Processed...91.64%
# 2787 Documents Processed...91.68%
# 2788 Documents Processed...91.71%
# 2789 Documents Processed...91.74%
# 2790 Documents Processed...91.78%
# 2791 Documents Processed...91.81%
# 2792 Documents Processed...91.84%
# 2793 Documents Processed...91.88%
# 2794 Documents Processed...91.91%
# 2795 Documents Processed...91.94%
# 2796 Documents Processed...91.97%
# 2797 Documents Processed...92.01%
# 2798 Documents Processed...92.04%
# 2799 Documents Processed...92.07%
# 2800 Documents Processed...92.11%
# 2801 Documents Processed...92.14%
# 2802 Documents Processed...92.17%
# 2803 Documents Processed...92.2%
# 2804 Documents Processed...92.24%
# 2805 Documents Processed...92.27%
# 2806 Documents Processed...92.3%
# 2807 Documents Processed...92.34%
# 2808 Documents Processed...92.37%
# 2809 Documents Processed...92.4%
# 2810 Documents Processed...92.43%
# 2811 Documents Processed...92.47%
# 2812 Documents Processed...92.5%
# 2813 Documents Processed...92.53%
# 2814 Documents Processed...92.57%
# 2815 Documents Processed...92.6%
# 2816 Documents Processed...92.63%
# 2817 Documents Processed...92.66%
# 2818 Documents Processed...92.7%
# 2819 Documents Processed...92.73%
# 2820 Documents Processed...92.76%
# 2821 Documents Processed...92.8%
# 2822 Documents Processed...92.83%
# 2823 Documents Processed...92.86%
# 2824 Documents Processed...92.89%
# 2825 Documents Processed...92.93%
# 2826 Documents Processed...92.96%
# 2827 Documents Processed...92.99%
# 2828 Documents Processed...93.03%
# 2829 Documents Processed...93.06%
# 2830 Documents Processed...93.09%
# 2831 Documents Processed...93.12%
# 2832 Documents Processed...93.16%
# 2833 Documents Processed...93.19%
# 2834 Documents Processed...93.22%
# 2835 Documents Processed...93.26%
# 2836 Documents Processed...93.29%
# 2837 Documents Processed...93.32%
# 2838 Documents Processed...93.36%
# 2839 Documents Processed...93.39%
# 2840 Documents Processed...93.42%
# 2841 Documents Processed...93.45%
# 2842 Documents Processed...93.49%
# 2843 Documents Processed...93.52%
# 2844 Documents Processed...93.55%
# 2845 Documents Processed...93.59%
# 2846 Documents Processed...93.62%
# 2847 Documents Processed...93.65%
# 2848 Documents Processed...93.68%
# 2849 Documents Processed...93.72%
# 2850 Documents Processed...93.75%
# 2851 Documents Processed...93.78%
# 2852 Documents Processed...93.82%
# 2853 Documents Processed...93.85%
# 2854 Documents Processed...93.88%
# 2855 Documents Processed...93.91%
# 2856 Documents Processed...93.95%
# 2857 Documents Processed...93.98%
# 2858 Documents Processed...94.01%
# 2859 Documents Processed...94.05%
# 2860 Documents Processed...94.08%
# 2861 Documents Processed...94.11%
# 2862 Documents Processed...94.14%
# 2863 Documents Processed...94.18%
# 2864 Documents Processed...94.21%
# 2865 Documents Processed...94.24%
# 2866 Documents Processed...94.28%
# 2867 Documents Processed...94.31%
# 2868 Documents Processed...94.34%
# 2869 Documents Processed...94.38%
# 2870 Documents Processed...94.41%
# 2871 Documents Processed...94.44%
# 2872 Documents Processed...94.47%
# 2873 Documents Processed...94.51%
# 2874 Documents Processed...94.54%
# 2875 Documents Processed...94.57%
# 2876 Documents Processed...94.61%
# 2877 Documents Processed...94.64%
# 2878 Documents Processed...94.67%
# 2879 Documents Processed...94.7%
# 2880 Documents Processed...94.74%
# 2881 Documents Processed...94.77%
# 2882 Documents Processed...94.8%
# 2883 Documents Processed...94.84%
# 2884 Documents Processed...94.87%
# 2885 Documents Processed...94.9%
# 2886 Documents Processed...94.93%
# 2887 Documents Processed...94.97%
# 2888 Documents Processed...95.0%
# 2889 Documents Processed...95.03%
# 2890 Documents Processed...95.07%
# 2891 Documents Processed...95.1%
# 2892 Documents Processed...95.13%
# 2893 Documents Processed...95.16%
# 2894 Documents Processed...95.2%
# 2895 Documents Processed...95.23%
# 2896 Documents Processed...95.26%
# 2897 Documents Processed...95.3%
# 2898 Documents Processed...95.33%
# 2899 Documents Processed...95.36%
# 2900 Documents Processed...95.39%
# 2901 Documents Processed...95.43%
# 2902 Documents Processed...95.46%
# 2903 Documents Processed...95.49%
# 2904 Documents Processed...95.53%
# 2905 Documents Processed...95.56%
# 2906 Documents Processed...95.59%
# 2907 Documents Processed...95.62%
# 2908 Documents Processed...95.66%
# 2909 Documents Processed...95.69%
# 2910 Documents Processed...95.72%
# 2911 Documents Processed...95.76%
# 2912 Documents Processed...95.79%
# 2913 Documents Processed...95.82%
# 2914 Documents Processed...95.86%
# 2915 Documents Processed...95.89%
# 2916 Documents Processed...95.92%
# 2917 Documents Processed...95.95%
# 2918 Documents Processed...95.99%
# 2919 Documents Processed...96.02%
# 2920 Documents Processed...96.05%
# 2921 Documents Processed...96.09%
# 2922 Documents Processed...96.12%
# 2923 Documents Processed...96.15%
# 2924 Documents Processed...96.18%
# 2925 Documents Processed...96.22%
# 2926 Documents Processed...96.25%
# 2927 Documents Processed...96.28%
# 2928 Documents Processed...96.32%
# 2929 Documents Processed...96.35%
# 2930 Documents Processed...96.38%
# 2931 Documents Processed...96.41%
# 2932 Documents Processed...96.45%
# 2933 Documents Processed...96.48%
# 2934 Documents Processed...96.51%
# 2935 Documents Processed...96.55%
# 2936 Documents Processed...96.58%
# 2937 Documents Processed...96.61%
# 2938 Documents Processed...96.64%
# 2939 Documents Processed...96.68%
# 2940 Documents Processed...96.71%
# 2941 Documents Processed...96.74%
# 2942 Documents Processed...96.78%
# 2943 Documents Processed...96.81%
# 2944 Documents Processed...96.84%
# 2945 Documents Processed...96.88%
# 2946 Documents Processed...96.91%
# 2947 Documents Processed...96.94%
# 2948 Documents Processed...96.97%
# 2949 Documents Processed...97.01%
# 2950 Documents Processed...97.04%
# 2951 Documents Processed...97.07%
# 2952 Documents Processed...97.11%
# 2953 Documents Processed...97.14%
# 2954 Documents Processed...97.17%
# 2955 Documents Processed...97.2%
# 2956 Documents Processed...97.24%
# 2957 Documents Processed...97.27%
# 2958 Documents Processed...97.3%
# 2959 Documents Processed...97.34%
# 2960 Documents Processed...97.37%
# 2961 Documents Processed...97.4%
# 2962 Documents Processed...97.43%
# 2963 Documents Processed...97.47%
# 2964 Documents Processed...97.5%
# 2965 Documents Processed...97.53%
# 2966 Documents Processed...97.57%
# 2967 Documents Processed...97.6%
# 2968 Documents Processed...97.63%
# 2969 Documents Processed...97.66%
# 2970 Documents Processed...97.7%
# 2971 Documents Processed...97.73%
# 2972 Documents Processed...97.76%
# 2973 Documents Processed...97.8%
# 2974 Documents Processed...97.83%
# 2975 Documents Processed...97.86%
# 2976 Documents Processed...97.89%
# 2977 Documents Processed...97.93%
# 2978 Documents Processed...97.96%
# 2979 Documents Processed...97.99%
# 2980 Documents Processed...98.03%
# 2981 Documents Processed...98.06%
# 2982 Documents Processed...98.09%
# 2983 Documents Processed...98.12%
# 2984 Documents Processed...98.16%
# 2985 Documents Processed...98.19%
# 2986 Documents Processed...98.22%
# 2987 Documents Processed...98.26%
# 2988 Documents Processed...98.29%
# 2989 Documents Processed...98.32%
# 2990 Documents Processed...98.36%
# 2991 Documents Processed...98.39%
# 2992 Documents Processed...98.42%
# 2993 Documents Processed...98.45%
# 2994 Documents Processed...98.49%
# 2995 Documents Processed...98.52%
# 2996 Documents Processed...98.55%
# 2997 Documents Processed...98.59%
# 2998 Documents Processed...98.62%
# 2999 Documents Processed...98.65%
# 3000 Documents Processed...98.68%
# 3001 Documents Processed...98.72%
# 3002 Documents Processed...98.75%
# 3003 Documents Processed...98.78%
# 3004 Documents Processed...98.82%
# 3005 Documents Processed...98.85%
# 3006 Documents Processed...98.88%
# 3007 Documents Processed...98.91%
# 3008 Documents Processed...98.95%
# 3009 Documents Processed...98.98%
# 3010 Documents Processed...99.01%
# 3011 Documents Processed...99.05%
# 3012 Documents Processed...99.08%
# 3013 Documents Processed...99.11%
# 3014 Documents Processed...99.14%
# 3015 Documents Processed...99.18%
# 3016 Documents Processed...99.21%
# 3017 Documents Processed...99.24%
# 3018 Documents Processed...99.28%
# 3019 Documents Processed...99.31%
# 3020 Documents Processed...99.34%
# 3021 Documents Processed...99.38%
# 3022 Documents Processed...99.41%
# 3023 Documents Processed...99.44%
# 3024 Documents Processed...99.47%
# 3025 Documents Processed...99.51%
# 3026 Documents Processed...99.54%
# 3027 Documents Processed...99.57%
# 3028 Documents Processed...99.61%
# 3029 Documents Processed...99.64%
# 3030 Documents Processed...99.67%
# 3031 Documents Processed...99.7%
# 3032 Documents Processed...99.74%
# 3033 Documents Processed...99.77%
# 3034 Documents Processed...99.8%
# 3035 Documents Processed...99.84%
# 3036 Documents Processed...99.87%
# 3037 Documents Processed...99.9%
# 3038 Documents Processed...99.93%
# 3039 Documents Processed...99.97%
# 3040 Documents Processed...100.0%

# %%
averaged_tester = tf.convert_to_tensor(pooled_outputs)
averaged_tester.shape
# Out:
# TensorShape([3040, 512, 768])

# %%
pooled_input = tf.keras.layers.Input(shape=(512, 768), dtype=tf.float32, name='Pooled Input')
dropout = tf.keras.layers.Dropout(0.1)(pooled_input)
dense = tf.keras.layers.Dense(2, activation='softmax', input_dim=1, name='Dense')(dropout)

model = tf.keras.Model(pooled_input, dense)
model.summary()

from transformers import create_optimizer
import tensorflow as tf

optimiser = tf.optimizers.Adam(learning_rate= 5e-5)
#BINARY CROSSENTROPY SHOULD BE HERE, NO?
model.compile(loss="sparse_categorical_crossentropy",optimizer=optimiser)

model.fit(averaged_tester,train_y,epochs=5,batch_size=1)
# Out:
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Pooled Input (InputLayer)   [(None, 512, 768)]        0
#
#  dropout_41 (Dropout)        (None, 512, 768)          0
#
#  Dense (Dense)               (None, 512, 2)            1538
#
# =================================================================
# Total params: 1,538
# Trainable params: 1,538
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16904/2143850066.py in <module>
#      13 model.compile(loss="sparse_categorical_crossentropy",optimizer=optimiser)
#      14
# ---> 15 model.fit(averaged_tester,train_y,epochs=5,batch_size=1)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 809, in train_step
#         loss = self.compiled_loss(
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\losses.py", line 1737, in sparse_categorical_crossentropy
#         return backend.sparse_categorical_crossentropy(
#     File "C:\Users\jack-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\backend.py", line 5113, in sparse_categorical_crossentropy
#         res = tf.nn.sparse_softmax_cross_entropy_with_logits(
#
#     ValueError: `labels.shape` must equal `logits.shape` except for the last dimension. Received: labels.shape=(1,) and logits.shape=(512, 2)

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import precision_score
from sklearn.metrics import make_scorer

test_pooled_outputs = []
i = 1
for sample in test_x:
    test_pooled_outputs.append(get_pooled_outputs_v2(sample))
    print(str(i) + " Documents Processed..." + str( round( (i/len(test_x)) * 100, 2)) + "%")
    i += 1

# %%
predictions = model.predict(test_samples)
bin_preds = []
for pred in predictions:
    if pred[1] > pred[0]:
        bin_preds.append(1)
    else:
        bin_preds.append(0)

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import precision_score
from sklearn.metrics import make_scorer

precision = precision_score(test_y, bin_preds)
bac = balanced_accuracy_score(test_y, bin_preds)
f2 = fbeta_score(test_y, bin_preds, beta=2.0)
print(precision,bac,f2)
