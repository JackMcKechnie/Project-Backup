# %%
# Imports
import pandas as pd
from regression_table import regression_table
import math

# %%
# Squinky
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
feature_names = ["Informativeness","Implicature","Length in Words","Length in Characters","F-score","I-score","Lexical Density"]
squinky_table = regression_table(squinky,feature_names,"Nothing")
squinky_table
# Out:
#                                                   R Squared  \
# Linear Regression + Nothing                        0.565145
# Ridge Regression + Nothing                         0.565145
# Lasso Regression + Nothing                         0.300143
# LARS Lasso Regression + Nothing                    0.300143
# Bayesian Ridge Regression + Nothing                0.565142
# Stochastic Gradient Descent Regression + Nothing   0.562004
#
#                                                   Negative Mean Squared Error  \
# Linear Regression + Nothing                                         -0.549488
# Ridge Regression + Nothing                                          -0.549489
# Lasso Regression + Nothing                                          -0.884717
# LARS Lasso Regression + Nothing                                     -0.884717
# Bayesian Ridge Regression + Nothing                                 -0.549493
# Stochastic Gradient Descent Regression + Nothing                    -0.436957
#
#                                                   Negative Mean Absolute Error  \
# Linear Regression + Nothing                                          -0.504211
# Ridge Regression + Nothing                                           -0.504208
# Lasso Regression + Nothing                                           -0.662467
# LARS Lasso Regression + Nothing                                      -0.662467
# Bayesian Ridge Regression + Nothing                                  -0.504274
# Stochastic Gradient Descent Regression + Nothing                     -0.452130
#
#                                                   Max Error
# Linear Regression + Nothing                       -2.818254
# Ridge Regression + Nothing                        -2.818464
# Lasso Regression + Nothing                        -3.815242
# LARS Lasso Regression + Nothing                   -3.815244
# Bayesian Ridge Regression + Nothing               -2.820239
# Stochastic Gradient Descent Regression + Nothing  -2.359565

# %%
# Squinky + Lexical scores
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
lexical = pd.read_csv("..\..\data\squinky_lexical.csv",encoding="unicode escape")
squinky_lexical = pd.merge(squinky,lexical)


feature_names = ["Informativeness","Implicature","Length in Words","Length in Characters","F-score","I-score","Lexical Density","Adjective Density","Spellcheck Percentage","Syllable Ratio","Latinate vs Germanic"]
squinky_lexical_table = regression_table(squinky_lexical,feature_names,"Lexical")
squinky_lexical_table
# Out:
#                                                   R Squared  \
# Linear Regression + Lexical                        0.587687
# Ridge Regression + Lexical                         0.587688
# Lasso Regression + Lexical                         0.340043
# LARS Lasso Regression + Lexical                    0.340043
# Bayesian Ridge Regression + Lexical                0.587691
# Stochastic Gradient Descent Regression + Lexical   0.586027
#
#                                                   Negative Mean Squared Error  \
# Linear Regression + Lexical                                         -0.525732
# Ridge Regression + Lexical                                          -0.525730
# Lasso Regression + Lexical                                          -0.841280
# LARS Lasso Regression + Lexical                                     -0.841280
# Bayesian Ridge Regression + Lexical                                 -0.525723
# Stochastic Gradient Descent Regression + Lexical                    -0.412933
#
#                                                   Negative Mean Absolute Error  \
# Linear Regression + Lexical                                          -0.497943
# Ridge Regression + Lexical                                           -0.497900
# Lasso Regression + Lexical                                           -0.646846
# LARS Lasso Regression + Lexical                                      -0.646846
# Bayesian Ridge Regression + Lexical                                  -0.497619
# Stochastic Gradient Descent Regression + Lexical                     -0.438765
#
#                                                   Max Error
# Linear Regression + Lexical                       -2.677116
# Ridge Regression + Lexical                        -2.677393
# Lasso Regression + Lexical                        -3.851575
# LARS Lasso Regression + Lexical                   -3.851570
# Bayesian Ridge Regression + Lexical               -2.680961
# Stochastic Gradient Descent Regression + Lexical  -2.255274

# %%
#Squinky + Scores

squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
scores = pd.read_csv("..\..\data\squinky_scores.csv",encoding="unicode escape")
squinky_scores = pd.merge(squinky,scores)

feature_names = ["Informativeness","Implicature","Length in Words","Length in Characters","F-score","I-score","Lexical Density","ADF Score","FK Grade Level","Reading Time","WF Score"]
squinky_scores_table = regression_table(squinky_scores,feature_names,"Scores")
squinky_scores_table
# Out:
#                                                  R Squared  \
# Linear Regression + Scores                        0.575551
# Ridge Regression + Scores                         0.571516
# Lasso Regression + Scores                         0.302720
# LARS Lasso Regression + Scores                    0.302720
# Bayesian Ridge Regression + Scores                0.570390
# Stochastic Gradient Descent Regression + Scores   0.566936
#
#                                                  Negative Mean Squared Error  \
# Linear Regression + Scores                                         -0.541242
# Ridge Regression + Scores                                          -0.546264
# Lasso Regression + Scores                                          -0.888835
# LARS Lasso Regression + Scores                                     -0.888835
# Bayesian Ridge Regression + Scores                                 -0.547678
# Stochastic Gradient Descent Regression + Scores                    -0.431793
#
#                                                  Negative Mean Absolute Error  \
# Linear Regression + Scores                                          -0.498536
# Ridge Regression + Scores                                           -0.496753
# Lasso Regression + Scores                                           -0.660741
# LARS Lasso Regression + Scores                                      -0.660741
# Bayesian Ridge Regression + Scores                                  -0.498207
# Stochastic Gradient Descent Regression + Scores                     -0.443676
#
#                                                  Max Error
# Linear Regression + Scores                       -2.649248
# Ridge Regression + Scores                        -2.741367
# Lasso Regression + Scores                        -4.024839
# LARS Lasso Regression + Scores                   -4.024845
# Bayesian Ridge Regression + Scores               -2.767199
# Stochastic Gradient Descent Regression + Scores  -2.418635

# %%
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
reading = pd.read_csv("..\..\data\squinky_reading.csv",encoding="unicode escape")
squinky_reading = pd.merge(squinky,reading)

feature_names = ["Informativeness","Implicature","Length in Words","Length in Characters","F-score","I-score","Lexical Density","FK Reading Ease","FOG Scale","SMOG Index","ARI","CL Index","LW Formula","DC Score","Readability Consensus","Spache Formula"]
squinky_reading_table = regression_table(squinky_reading,feature_names,"Reading")
squinky_reading_table
# Out:
#                                                   R Squared  \
# Linear Regression + Reading                        0.587271
# Ridge Regression + Reading                         0.587271
# Lasso Regression + Reading                         0.317949
# LARS Lasso Regression + Reading                    0.317949
# Bayesian Ridge Regression + Reading                0.587267
# Stochastic Gradient Descent Regression + Reading   0.584028
#
#                                                   Negative Mean Squared Error  \
# Linear Regression + Reading                                         -0.526103
# Ridge Regression + Reading                                          -0.526102
# Lasso Regression + Reading                                          -0.869339
# LARS Lasso Regression + Reading                                     -0.869339
# Bayesian Ridge Regression + Reading                                 -0.526107
# Stochastic Gradient Descent Regression + Reading                    -0.414722
#
#                                                   Negative Mean Absolute Error  \
# Linear Regression + Reading                                          -0.484285
# Ridge Regression + Reading                                           -0.484328
# Lasso Regression + Reading                                           -0.650747
# LARS Lasso Regression + Reading                                      -0.650747
# Bayesian Ridge Regression + Reading                                  -0.484268
# Stochastic Gradient Descent Regression + Reading                     -0.428523
#
#                                                   Max Error
# Linear Regression + Reading                       -2.605717
# Ridge Regression + Reading                        -2.605752
# Lasso Regression + Reading                        -3.864657
# LARS Lasso Regression + Reading                   -3.864671
# Bayesian Ridge Regression + Reading               -2.606530
# Stochastic Gradient Descent Regression + Reading  -2.203451

# %%
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
nlp = pd.read_csv("..\..\data\squinky_nlp.csv")
squinky_nlp = pd.merge(squinky,nlp)

feature_names = ["Informativeness","Implicature","Length in Words","Length in Characters","F-score","I-score","Lexical Density","Cluster","Topic"]
squinky_nlp_table = regression_table(squinky_nlp,feature_names,"NLP")
squinky_nlp_table
# Out:
#                                               R Squared  \
# Linear Regression + NLP                        0.566994
# Ridge Regression + NLP                         0.566993
# Lasso Regression + NLP                         0.300143
# LARS Lasso Regression + NLP                    0.300143
# Bayesian Ridge Regression + NLP                0.566989
# Stochastic Gradient Descent Regression + NLP   0.562961
#
#                                               Negative Mean Squared Error  \
# Linear Regression + NLP                                         -0.547151
# Ridge Regression + NLP                                          -0.547151
# Lasso Regression + NLP                                          -0.884717
# LARS Lasso Regression + NLP                                     -0.884717
# Bayesian Ridge Regression + NLP                                 -0.547157
# Stochastic Gradient Descent Regression + NLP                    -0.436019
#
#                                               Negative Mean Absolute Error  \
# Linear Regression + NLP                                          -0.500305
# Ridge Regression + NLP                                           -0.500290
# Lasso Regression + NLP                                           -0.662467
# LARS Lasso Regression + NLP                                      -0.662467
# Bayesian Ridge Regression + NLP                                  -0.500062
# Stochastic Gradient Descent Regression + NLP                     -0.451505
#
#                                               Max Error
# Linear Regression + NLP                       -2.801958
# Ridge Regression + NLP                        -2.802130
# Lasso Regression + NLP                        -3.815242
# LARS Lasso Regression + NLP                   -3.815244
# Bayesian Ridge Regression + NLP               -2.804063
# Stochastic Gradient Descent Regression + NLP  -2.327604

# %%
data_frames = [squinky, lexical, scores, reading, nlp]
total = pd.concat(data_frames, axis=1)

feature_names = ['Informativeness', 'Implicature',
                 'Length in Words', 'Length in Characters', 'F-score', 'I-score',
                 'Lexical Density', 'Adjective Density',
                 'Spellcheck Percentage', 'Syllable Ratio', 'Latinate vs Germanic', 'ADF Score', 'FK Grade Level', 'Reading Time', 'WF Score', 'FK Reading Ease', 'FOG Scale', 'SMOG Index', 'ARI',
                 'CL Index', 'LW Formula', 'DC Score', 'Readability Consensus',
                 'Spache Formula','Cluster', 'Topic']


total_table = regression_table(total,feature_names,"All")
total_table
# Out:
#                                               R Squared  \
# Linear Regression + All                        0.596624
# Ridge Regression + All                         0.595649
# Lasso Regression + All                         0.351537
# LARS Lasso Regression + All                    0.351538
# Bayesian Ridge Regression + All                0.595487
# Stochastic Gradient Descent Regression + All   0.590283
#
#                                               Negative Mean Squared Error  \
# Linear Regression + All                                         -0.509637
# Ridge Regression + All                                          -0.510922
# Lasso Regression + All                                          -0.819784
# LARS Lasso Regression + All                                     -0.819784
# Bayesian Ridge Regression + All                                 -0.511146
# Stochastic Gradient Descent Regression + All                    -0.408773
#
#                                               Negative Mean Absolute Error  \
# Linear Regression + All                                          -0.485782
# Ridge Regression + All                                           -0.488477
# Lasso Regression + All                                           -0.628941
# LARS Lasso Regression + All                                      -0.628940
# Bayesian Ridge Regression + All                                  -0.489176
# Stochastic Gradient Descent Regression + All                     -0.438771
#
#                                               Max Error
# Linear Regression + All                       -2.473574
# Ridge Regression + All                        -2.506374
# Lasso Regression + All                        -3.601711
# LARS Lasso Regression + All                   -3.601725
# Bayesian Ridge Regression + All               -2.525626
# Stochastic Gradient Descent Regression + All  -2.289164

# %%
combined_table = pd.concat([squinky_table,squinky_lexical_table,squinky_scores_table,squinky_reading_table,squinky_nlp_table,total_table])

#combined_table.to_csv("../../data/combined_regression_scores.csv")
combined_table
# Out:
#                                                   R Squared  \
# Linear Regression + Nothing                        0.565145
# Ridge Regression + Nothing                         0.565145
# Lasso Regression + Nothing                         0.300143
# LARS Lasso Regression + Nothing                    0.300143
# Bayesian Ridge Regression + Nothing                0.565142
# Stochastic Gradient Descent Regression + Nothing   0.562004
# Linear Regression + Lexical                        0.587687
# Ridge Regression + Lexical                         0.587688
# Lasso Regression + Lexical                         0.340043
# LARS Lasso Regression + Lexical                    0.340043
# Bayesian Ridge Regression + Lexical                0.587691
# Stochastic Gradient Descent Regression + Lexical   0.586027
# Linear Regression + Scores                         0.575551
# Ridge Regression + Scores                          0.571516
# Lasso Regression + Scores                          0.302720
# LARS Lasso Regression + Scores                     0.302720
# Bayesian Ridge Regression + Scores                 0.570390
# Stochastic Gradient Descent Regression + Scores    0.566936
# Linear Regression + Reading                        0.587271
# Ridge Regression + Reading                         0.587271
# Lasso Regression + Reading                         0.317949
# LARS Lasso Regression + Reading                    0.317949
# Bayesian Ridge Regression + Reading                0.587267
# Stochastic Gradient Descent Regression + Reading   0.584028
# Linear Regression + NLP                            0.566994
# Ridge Regression + NLP                             0.566993
# Lasso Regression + NLP                             0.300143
# LARS Lasso Regression + NLP                        0.300143
# Bayesian Ridge Regression + NLP                    0.566989
# Stochastic Gradient Descent Regression + NLP       0.562961
# Linear Regression + All                            0.596624
# Ridge Regression + All                             0.595649
# Lasso Regression + All                             0.351537
# LARS Lasso Regression + All                        0.351538
# Bayesian Ridge Regression + All                    0.595487
# Stochastic Gradient Descent Regression + All       0.590283
#
#                                                   Negative Mean Squared Error  \
# Linear Regression + Nothing                                         -0.549488
# Ridge Regression + Nothing                                          -0.549489
# Lasso Regression + Nothing                                          -0.884717
# LARS Lasso Regression + Nothing                                     -0.884717
# Bayesian Ridge Regression + Nothing                                 -0.549493
# Stochastic Gradient Descent Regression + Nothing                    -0.436957
# Linear Regression + Lexical                                         -0.525732
# Ridge Regression + Lexical                                          -0.525730
# Lasso Regression + Lexical                                          -0.841280
# LARS Lasso Regression + Lexical                                     -0.841280
# Bayesian Ridge Regression + Lexical                                 -0.525723
# Stochastic Gradient Descent Regression + Lexical                    -0.412933
# Linear Regression + Scores                                          -0.541242
# Ridge Regression + Scores                                           -0.546264
# Lasso Regression + Scores                                           -0.888835
# LARS Lasso Regression + Scores                                      -0.888835
# Bayesian Ridge Regression + Scores                                  -0.547678
# Stochastic Gradient Descent Regression + Scores                     -0.431793
# Linear Regression + Reading                                         -0.526103
# Ridge Regression + Reading                                          -0.526102
# Lasso Regression + Reading                                          -0.869339
# LARS Lasso Regression + Reading                                     -0.869339
# Bayesian Ridge Regression + Reading                                 -0.526107
# Stochastic Gradient Descent Regression + Reading                    -0.414722
# Linear Regression + NLP                                             -0.547151
# Ridge Regression + NLP                                              -0.547151
# Lasso Regression + NLP                                              -0.884717
# LARS Lasso Regression + NLP                                         -0.884717
# Bayesian Ridge Regression + NLP                                     -0.547157
# Stochastic Gradient Descent Regression + NLP                        -0.436019
# Linear Regression + All                                             -0.509637
# Ridge Regression + All                                              -0.510922
# Lasso Regression + All                                              -0.819784
# LARS Lasso Regression + All                                         -0.819784
# Bayesian Ridge Regression + All                                     -0.511146
# Stochastic Gradient Descent Regression + All                        -0.408773
#
#                                                   Negative Mean Absolute Error  \
# Linear Regression + Nothing                                          -0.504211
# Ridge Regression + Nothing                                           -0.504208
# Lasso Regression + Nothing                                           -0.662467
# LARS Lasso Regression + Nothing                                      -0.662467
# Bayesian Ridge Regression + Nothing                                  -0.504274
# Stochastic Gradient Descent Regression + Nothing                     -0.452130
# Linear Regression + Lexical                                          -0.497943
# Ridge Regression + Lexical                                           -0.497900
# Lasso Regression + Lexical                                           -0.646846
# LARS Lasso Regression + Lexical                                      -0.646846
# Bayesian Ridge Regression + Lexical                                  -0.497619
# Stochastic Gradient Descent Regression + Lexical                     -0.438765
# Linear Regression + Scores                                           -0.498536
# Ridge Regression + Scores                                            -0.496753
# Lasso Regression + Scores                                            -0.660741
# LARS Lasso Regression + Scores                                       -0.660741
# Bayesian Ridge Regression + Scores                                   -0.498207
# Stochastic Gradient Descent Regression + Scores                      -0.443676
# Linear Regression + Reading                                          -0.484285
# Ridge Regression + Reading                                           -0.484328
# Lasso Regression + Reading                                           -0.650747
# LARS Lasso Regression + Reading                                      -0.650747
# Bayesian Ridge Regression + Reading                                  -0.484268
# Stochastic Gradient Descent Regression + Reading                     -0.428523
# Linear Regression + NLP                                              -0.500305
# Ridge Regression + NLP                                               -0.500290
# Lasso Regression + NLP                                               -0.662467
# LARS Lasso Regression + NLP                                          -0.662467
# Bayesian Ridge Regression + NLP                                      -0.500062
# Stochastic Gradient Descent Regression + NLP                         -0.451505
# Linear Regression + All                                              -0.485782
# Ridge Regression + All                                               -0.488477
# Lasso Regression + All                                               -0.628941
# LARS Lasso Regression + All                                          -0.628940
# Bayesian Ridge Regression + All                                      -0.489176
# Stochastic Gradient Descent Regression + All                         -0.438771
#
#                                                   Max Error
# Linear Regression + Nothing                       -2.818254
# Ridge Regression + Nothing                        -2.818464
# Lasso Regression + Nothing                        -3.815242
# LARS Lasso Regression + Nothing                   -3.815244
# Bayesian Ridge Regression + Nothing               -2.820239
# Stochastic Gradient Descent Regression + Nothing  -2.359565
# Linear Regression + Lexical                       -2.677116
# Ridge Regression + Lexical                        -2.677393
# Lasso Regression + Lexical                        -3.851575
# LARS Lasso Regression + Lexical                   -3.851570
# Bayesian Ridge Regression + Lexical               -2.680961
# Stochastic Gradient Descent Regression + Lexical  -2.255274
# Linear Regression + Scores                        -2.649248
# Ridge Regression + Scores                         -2.741367
# Lasso Regression + Scores                         -4.024839
# LARS Lasso Regression + Scores                    -4.024845
# Bayesian Ridge Regression + Scores                -2.767199
# Stochastic Gradient Descent Regression + Scores   -2.418635
# Linear Regression + Reading                       -2.605717
# Ridge Regression + Reading                        -2.605752
# Lasso Regression + Reading                        -3.864657
# LARS Lasso Regression + Reading                   -3.864671
# Bayesian Ridge Regression + Reading               -2.606530
# Stochastic Gradient Descent Regression + Reading  -2.203451
# Linear Regression + NLP                           -2.801958
# Ridge Regression + NLP                            -2.802130
# Lasso Regression + NLP                            -3.815242
# LARS Lasso Regression + NLP                       -3.815244
# Bayesian Ridge Regression + NLP                   -2.804063
# Stochastic Gradient Descent Regression + NLP      -2.327604
# Linear Regression + All                           -2.473574
# Ridge Regression + All                            -2.506374
# Lasso Regression + All                            -3.601711
# LARS Lasso Regression + All                       -3.601725
# Bayesian Ridge Regression + All                   -2.525626
# Stochastic Gradient Descent Regression + All      -2.289164

# %%
combined_table["R Squared"] = combined_table["R Squared"].apply(lambda x: round(x, 4 - int(math.floor(math.log10(abs(x))))))
combined_table
# Out:
#                                                   R Squared  \
# Linear Regression + Nothing                         0.56515
# Ridge Regression + Nothing                          0.56515
# Lasso Regression + Nothing                          0.30014
# LARS Lasso Regression + Nothing                     0.30014
# Bayesian Ridge Regression + Nothing                 0.56514
# Stochastic Gradient Descent Regression + Nothing    0.56200
# Linear Regression + Lexical                         0.58769
# Ridge Regression + Lexical                          0.58769
# Lasso Regression + Lexical                          0.34004
# LARS Lasso Regression + Lexical                     0.34004
# Bayesian Ridge Regression + Lexical                 0.58769
# Stochastic Gradient Descent Regression + Lexical    0.58603
# Linear Regression + Scores                          0.57555
# Ridge Regression + Scores                           0.57152
# Lasso Regression + Scores                           0.30272
# LARS Lasso Regression + Scores                      0.30272
# Bayesian Ridge Regression + Scores                  0.57039
# Stochastic Gradient Descent Regression + Scores     0.56694
# Linear Regression + Reading                         0.58727
# Ridge Regression + Reading                          0.58727
# Lasso Regression + Reading                          0.31795
# LARS Lasso Regression + Reading                     0.31795
# Bayesian Ridge Regression + Reading                 0.58727
# Stochastic Gradient Descent Regression + Reading    0.58403
# Linear Regression + NLP                             0.56699
# Ridge Regression + NLP                              0.56699
# Lasso Regression + NLP                              0.30014
# LARS Lasso Regression + NLP                         0.30014
# Bayesian Ridge Regression + NLP                     0.56699
# Stochastic Gradient Descent Regression + NLP        0.56296
# Linear Regression + All                             0.59662
# Ridge Regression + All                              0.59565
# Lasso Regression + All                              0.35154
# LARS Lasso Regression + All                         0.35154
# Bayesian Ridge Regression + All                     0.59549
# Stochastic Gradient Descent Regression + All        0.59028
#
#                                                   Negative Mean Squared Error  \
# Linear Regression + Nothing                                         -0.549488
# Ridge Regression + Nothing                                          -0.549489
# Lasso Regression + Nothing                                          -0.884717
# LARS Lasso Regression + Nothing                                     -0.884717
# Bayesian Ridge Regression + Nothing                                 -0.549493
# Stochastic Gradient Descent Regression + Nothing                    -0.436957
# Linear Regression + Lexical                                         -0.525732
# Ridge Regression + Lexical                                          -0.525730
# Lasso Regression + Lexical                                          -0.841280
# LARS Lasso Regression + Lexical                                     -0.841280
# Bayesian Ridge Regression + Lexical                                 -0.525723
# Stochastic Gradient Descent Regression + Lexical                    -0.412933
# Linear Regression + Scores                                          -0.541242
# Ridge Regression + Scores                                           -0.546264
# Lasso Regression + Scores                                           -0.888835
# LARS Lasso Regression + Scores                                      -0.888835
# Bayesian Ridge Regression + Scores                                  -0.547678
# Stochastic Gradient Descent Regression + Scores                     -0.431793
# Linear Regression + Reading                                         -0.526103
# Ridge Regression + Reading                                          -0.526102
# Lasso Regression + Reading                                          -0.869339
# LARS Lasso Regression + Reading                                     -0.869339
# Bayesian Ridge Regression + Reading                                 -0.526107
# Stochastic Gradient Descent Regression + Reading                    -0.414722
# Linear Regression + NLP                                             -0.547151
# Ridge Regression + NLP                                              -0.547151
# Lasso Regression + NLP                                              -0.884717
# LARS Lasso Regression + NLP                                         -0.884717
# Bayesian Ridge Regression + NLP                                     -0.547157
# Stochastic Gradient Descent Regression + NLP                        -0.436019
# Linear Regression + All                                             -0.509637
# Ridge Regression + All                                              -0.510922
# Lasso Regression + All                                              -0.819784
# LARS Lasso Regression + All                                         -0.819784
# Bayesian Ridge Regression + All                                     -0.511146
# Stochastic Gradient Descent Regression + All                        -0.408773
#
#                                                   Negative Mean Absolute Error  \
# Linear Regression + Nothing                                          -0.504211
# Ridge Regression + Nothing                                           -0.504208
# Lasso Regression + Nothing                                           -0.662467
# LARS Lasso Regression + Nothing                                      -0.662467
# Bayesian Ridge Regression + Nothing                                  -0.504274
# Stochastic Gradient Descent Regression + Nothing                     -0.452130
# Linear Regression + Lexical                                          -0.497943
# Ridge Regression + Lexical                                           -0.497900
# Lasso Regression + Lexical                                           -0.646846
# LARS Lasso Regression + Lexical                                      -0.646846
# Bayesian Ridge Regression + Lexical                                  -0.497619
# Stochastic Gradient Descent Regression + Lexical                     -0.438765
# Linear Regression + Scores                                           -0.498536
# Ridge Regression + Scores                                            -0.496753
# Lasso Regression + Scores                                            -0.660741
# LARS Lasso Regression + Scores                                       -0.660741
# Bayesian Ridge Regression + Scores                                   -0.498207
# Stochastic Gradient Descent Regression + Scores                      -0.443676
# Linear Regression + Reading                                          -0.484285
# Ridge Regression + Reading                                           -0.484328
# Lasso Regression + Reading                                           -0.650747
# LARS Lasso Regression + Reading                                      -0.650747
# Bayesian Ridge Regression + Reading                                  -0.484268
# Stochastic Gradient Descent Regression + Reading                     -0.428523
# Linear Regression + NLP                                              -0.500305
# Ridge Regression + NLP                                               -0.500290
# Lasso Regression + NLP                                               -0.662467
# LARS Lasso Regression + NLP                                          -0.662467
# Bayesian Ridge Regression + NLP                                      -0.500062
# Stochastic Gradient Descent Regression + NLP                         -0.451505
# Linear Regression + All                                              -0.485782
# Ridge Regression + All                                               -0.488477
# Lasso Regression + All                                               -0.628941
# LARS Lasso Regression + All                                          -0.628940
# Bayesian Ridge Regression + All                                      -0.489176
# Stochastic Gradient Descent Regression + All                         -0.438771
#
#                                                   Max Error
# Linear Regression + Nothing                       -2.818254
# Ridge Regression + Nothing                        -2.818464
# Lasso Regression + Nothing                        -3.815242
# LARS Lasso Regression + Nothing                   -3.815244
# Bayesian Ridge Regression + Nothing               -2.820239
# Stochastic Gradient Descent Regression + Nothing  -2.359565
# Linear Regression + Lexical                       -2.677116
# Ridge Regression + Lexical                        -2.677393
# Lasso Regression + Lexical                        -3.851575
# LARS Lasso Regression + Lexical                   -3.851570
# Bayesian Ridge Regression + Lexical               -2.680961
# Stochastic Gradient Descent Regression + Lexical  -2.255274
# Linear Regression + Scores                        -2.649248
# Ridge Regression + Scores                         -2.741367
# Lasso Regression + Scores                         -4.024839
# LARS Lasso Regression + Scores                    -4.024845
# Bayesian Ridge Regression + Scores                -2.767199
# Stochastic Gradient Descent Regression + Scores   -2.418635
# Linear Regression + Reading                       -2.605717
# Ridge Regression + Reading                        -2.605752
# Lasso Regression + Reading                        -3.864657
# LARS Lasso Regression + Reading                   -3.864671
# Bayesian Ridge Regression + Reading               -2.606530
# Stochastic Gradient Descent Regression + Reading  -2.203451
# Linear Regression + NLP                           -2.801958
# Ridge Regression + NLP                            -2.802130
# Lasso Regression + NLP                            -3.815242
# LARS Lasso Regression + NLP                       -3.815244
# Bayesian Ridge Regression + NLP                   -2.804063
# Stochastic Gradient Descent Regression + NLP      -2.327604
# Linear Regression + All                           -2.473574
# Ridge Regression + All                            -2.506374
# Lasso Regression + All                            -3.601711
# LARS Lasso Regression + All                       -3.601725
# Bayesian Ridge Regression + All                   -2.525626
# Stochastic Gradient Descent Regression + All      -2.289164
