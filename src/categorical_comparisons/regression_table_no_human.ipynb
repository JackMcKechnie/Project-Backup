# %%
# Imports
import pandas as pd
from regression_table import regression_table
import math

# %%
# Squinky
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
feature_names = ["Length in Words","Length in Characters","F-score","I-score","Lexical Density"]
squinky_table = regression_table(squinky,feature_names,"Nothing")
squinky_table
# Out:
#                                                   R Squared  \
# Linear Regression + Nothing                        0.334617
# Ridge Regression + Nothing                         0.334617
# Lasso Regression + Nothing                         0.315510
# LARS Lasso Regression + Nothing                    0.315510
# Bayesian Ridge Regression + Nothing                0.334589
# Stochastic Gradient Descent Regression + Nothing   0.327740
#
#                                                   Mean Squared Error  \
# Linear Regression + Nothing                                 0.853666
# Ridge Regression + Nothing                                  0.853666
# Lasso Regression + Nothing                                  0.878059
# LARS Lasso Regression + Nothing                             0.878059
# Bayesian Ridge Regression + Nothing                         0.853700
# Stochastic Gradient Descent Regression + Nothing            0.672103
#
#                                                   Mean Absolute Error  \
# Linear Regression + Nothing                                  0.646910
# Ridge Regression + Nothing                                   0.646909
# Lasso Regression + Nothing                                   0.660417
# LARS Lasso Regression + Nothing                              0.660417
# Bayesian Ridge Regression + Nothing                          0.647321
# Stochastic Gradient Descent Regression + Nothing             0.572950
#
#                                                   Max Error
# Linear Regression + Nothing                        4.069749
# Ridge Regression + Nothing                         4.069743
# Lasso Regression + Nothing                         4.009325
# LARS Lasso Regression + Nothing                    4.009328
# Bayesian Ridge Regression + Nothing                4.069349
# Stochastic Gradient Descent Regression + Nothing   3.673842

# %%
# Squinky + Lexical scores
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
lexical = pd.read_csv("..\..\data\squinky_lexical.csv",encoding="unicode escape")
squinky_lexical = pd.merge(squinky,lexical)


feature_names = ["Length in Words","Length in Characters","F-score","I-score","Lexical Density","Adjective Density","Spellcheck Percentage","Syllable Ratio","Latinate vs Germanic"]
squinky_lexical_table = regression_table(squinky_lexical,feature_names,"Lexical")
squinky_lexical_table
# Out:
#                                                   R Squared  \
# Linear Regression + Lexical                        0.374680
# Ridge Regression + Lexical                         0.374686
# Lasso Regression + Lexical                         0.337952
# LARS Lasso Regression + Lexical                    0.337952
# Bayesian Ridge Regression + Lexical                0.374114
# Stochastic Gradient Descent Regression + Lexical   0.368219
#
#                                                   Mean Squared Error  \
# Linear Regression + Lexical                                 0.797818
# Ridge Regression + Lexical                                  0.797809
# Lasso Regression + Lexical                                  0.844252
# LARS Lasso Regression + Lexical                             0.844252
# Bayesian Ridge Regression + Lexical                         0.798528
# Stochastic Gradient Descent Regression + Lexical            0.631087
#
#                                                   Mean Absolute Error  \
# Linear Regression + Lexical                                  0.627469
# Ridge Regression + Lexical                                   0.627569
# Lasso Regression + Lexical                                   0.658328
# LARS Lasso Regression + Lexical                              0.658327
# Bayesian Ridge Regression + Lexical                          0.626383
# Stochastic Gradient Descent Regression + Lexical             0.553917
#
#                                                   Max Error
# Linear Regression + Lexical                        3.367063
# Ridge Regression + Lexical                         3.366594
# Lasso Regression + Lexical                         3.451760
# LARS Lasso Regression + Lexical                    3.451758
# Bayesian Ridge Regression + Lexical                3.357252
# Stochastic Gradient Descent Regression + Lexical   3.098743

# %%
#Squinky + Scores

squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
scores = pd.read_csv("..\..\data\squinky_scores.csv",encoding="unicode escape")
squinky_scores = pd.merge(squinky,scores)

feature_names = ["Length in Words","Length in Characters","F-score","I-score","Lexical Density","ADF Score","FK Grade Level","Reading Time","WF Score"]
squinky_scores_table = regression_table(squinky_scores,feature_names,"Scores")
squinky_scores_table
# Out:
#                                                  R Squared  \
# Linear Regression + Scores                        0.352453
# Ridge Regression + Scores                         0.343327
# Lasso Regression + Scores                         0.304268
# LARS Lasso Regression + Scores                    0.304268
# Bayesian Ridge Regression + Scores                0.344993
# Stochastic Gradient Descent Regression + Scores   0.336080
#
#                                                  Mean Squared Error  \
# Linear Regression + Scores                                 0.825596
# Ridge Regression + Scores                                  0.837291
# Lasso Regression + Scores                                  0.886985
# LARS Lasso Regression + Scores                             0.886985
# Bayesian Ridge Regression + Scores                         0.835038
# Stochastic Gradient Descent Regression + Scores            0.662697
#
#                                                  Mean Absolute Error  \
# Linear Regression + Scores                                  0.641325
# Ridge Regression + Scores                                   0.647369
# Lasso Regression + Scores                                   0.670088
# LARS Lasso Regression + Scores                              0.670088
# Bayesian Ridge Regression + Scores                          0.643287
# Stochastic Gradient Descent Regression + Scores             0.576154
#
#                                                  Max Error
# Linear Regression + Scores                        3.013166
# Ridge Regression + Scores                         3.290670
# Lasso Regression + Scores                         3.551687
# LARS Lasso Regression + Scores                    3.551690
# Bayesian Ridge Regression + Scores                3.336508
# Stochastic Gradient Descent Regression + Scores   2.948103

# %%
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
reading = pd.read_csv("..\..\data\squinky_reading.csv",encoding="unicode escape")
squinky_reading = pd.merge(squinky,reading)

feature_names = ["Length in Words","Length in Characters","F-score","I-score","Lexical Density","FK Reading Ease","FOG Scale","SMOG Index","ARI","CL Index","LW Formula","DC Score","Readability Consensus","Spache Formula"]
squinky_reading_table = regression_table(squinky_reading,feature_names,"Reading")
squinky_reading_table
# Out:
#                                                   R Squared  \
# Linear Regression + Reading                        0.409276
# Ridge Regression + Reading                         0.409276
# Lasso Regression + Reading                         0.319177
# LARS Lasso Regression + Reading                    0.319177
# Bayesian Ridge Regression + Reading                0.409317
# Stochastic Gradient Descent Regression + Reading   0.407317
#
#                                                   Mean Squared Error  \
# Linear Regression + Reading                                 0.753231
# Ridge Regression + Reading                                  0.753230
# Lasso Regression + Reading                                  0.868053
# LARS Lasso Regression + Reading                             0.868053
# Bayesian Ridge Regression + Reading                         0.753193
# Stochastic Gradient Descent Regression + Reading            0.591577
#
#                                                   Mean Absolute Error  \
# Linear Regression + Reading                                  0.618510
# Ridge Regression + Reading                                   0.618509
# Lasso Regression + Reading                                   0.658865
# LARS Lasso Regression + Reading                              0.658864
# Bayesian Ridge Regression + Reading                          0.617701
# Stochastic Gradient Descent Regression + Reading             0.548467
#
#                                                   Max Error
# Linear Regression + Reading                        2.791561
# Ridge Regression + Reading                         2.791599
# Lasso Regression + Reading                         3.584759
# LARS Lasso Regression + Reading                    3.584759
# Bayesian Ridge Regression + Reading                2.806284
# Stochastic Gradient Descent Regression + Reading   2.482688

# %%
squinky = pd.read_csv("..\..\data\mturk_experiment_2.csv",encoding="unicode escape")
nlp = pd.read_csv("..\..\data\squinky_nlp.csv")
squinky_nlp = pd.merge(squinky,nlp)

feature_names = ["Length in Words","Length in Characters","F-score","I-score","Lexical Density","Cluster","Topic"]
squinky_nlp_table = regression_table(squinky_nlp,feature_names,"NLP")
squinky_nlp_table
# Out:
#                                               R Squared  Mean Squared Error  \
# Linear Regression + NLP                        0.342365            0.843679
# Ridge Regression + NLP                         0.342365            0.843679
# Lasso Regression + NLP                         0.315510            0.878059
# LARS Lasso Regression + NLP                    0.315510            0.878059
# Bayesian Ridge Regression + NLP                0.342338            0.843718
# Stochastic Gradient Descent Regression + NLP   0.335445            0.664379
#
#                                               Mean Absolute Error  Max Error
# Linear Regression + NLP                                  0.647948   3.966111
# Ridge Regression + NLP                                   0.647939   3.966116
# Lasso Regression + NLP                                   0.660417   4.009325
# LARS Lasso Regression + NLP                              0.660417   4.009328
# Bayesian Ridge Regression + NLP                          0.647459   3.968905
# Stochastic Gradient Descent Regression + NLP             0.575144   3.462673

# %%
data_frames = [squinky, lexical, scores, reading, nlp]
total = pd.concat(data_frames, axis=1)

feature_names = [
                 'Length in Words', 'Length in Characters', 'F-score', 'I-score',
                 'Lexical Density', 'Adjective Density',
                 'Spellcheck Percentage', 'Syllable Ratio', 'Latinate vs Germanic', 'ADF Score', 'FK Grade Level', 'Reading Time', 'WF Score', 'FK Reading Ease', 'FOG Scale', 'SMOG Index', 'ARI',
                 'CL Index', 'LW Formula', 'DC Score', 'Readability Consensus',
                 'Spache Formula','Cluster', 'Topic']


total_table = regression_table(total,feature_names,"All")
total_table
# Out:
#                                               R Squared  Mean Squared Error  \
# Linear Regression + All                        0.441109            0.716583
# Ridge Regression + All                         0.439918            0.718156
# Lasso Regression + All                         0.367710            0.811038
# LARS Lasso Regression + All                    0.367710            0.811038
# Bayesian Ridge Regression + All                0.439470            0.718780
# Stochastic Gradient Descent Regression + All   0.435030            0.564468
#
#                                               Mean Absolute Error  Max Error
# Linear Regression + All                                  0.591985   3.164138
# Ridge Regression + All                                   0.593553   3.284075
# Lasso Regression + All                                   0.627922   3.704123
# LARS Lasso Regression + All                              0.627924   3.704155
# Bayesian Ridge Regression + All                          0.590547   3.324117
# Stochastic Gradient Descent Regression + All             0.527515   2.937687

# %%
combined_table = pd.concat([squinky_table,squinky_lexical_table,squinky_scores_table,squinky_reading_table,squinky_nlp_table,total_table])

combined_table.to_csv("../../data/random_state_five/traditional_models_scores.csv")
combined_table
# Out:
#                                                   R Squared  \
# Linear Regression + Nothing                        0.334617
# Ridge Regression + Nothing                         0.334617
# Lasso Regression + Nothing                         0.315510
# LARS Lasso Regression + Nothing                    0.315510
# Bayesian Ridge Regression + Nothing                0.334589
# Stochastic Gradient Descent Regression + Nothing   0.327740
# Linear Regression + Lexical                        0.374680
# Ridge Regression + Lexical                         0.374686
# Lasso Regression + Lexical                         0.337952
# LARS Lasso Regression + Lexical                    0.337952
# Bayesian Ridge Regression + Lexical                0.374114
# Stochastic Gradient Descent Regression + Lexical   0.368219
# Linear Regression + Scores                         0.352453
# Ridge Regression + Scores                          0.343327
# Lasso Regression + Scores                          0.304268
# LARS Lasso Regression + Scores                     0.304268
# Bayesian Ridge Regression + Scores                 0.344993
# Stochastic Gradient Descent Regression + Scores    0.336080
# Linear Regression + Reading                        0.409276
# Ridge Regression + Reading                         0.409276
# Lasso Regression + Reading                         0.319177
# LARS Lasso Regression + Reading                    0.319177
# Bayesian Ridge Regression + Reading                0.409317
# Stochastic Gradient Descent Regression + Reading   0.407317
# Linear Regression + NLP                            0.342365
# Ridge Regression + NLP                             0.342365
# Lasso Regression + NLP                             0.315510
# LARS Lasso Regression + NLP                        0.315510
# Bayesian Ridge Regression + NLP                    0.342338
# Stochastic Gradient Descent Regression + NLP       0.335445
# Linear Regression + All                            0.441109
# Ridge Regression + All                             0.439918
# Lasso Regression + All                             0.367710
# LARS Lasso Regression + All                        0.367710
# Bayesian Ridge Regression + All                    0.439470
# Stochastic Gradient Descent Regression + All       0.435030
#
#                                                   Mean Squared Error  \
# Linear Regression + Nothing                                 0.853666
# Ridge Regression + Nothing                                  0.853666
# Lasso Regression + Nothing                                  0.878059
# LARS Lasso Regression + Nothing                             0.878059
# Bayesian Ridge Regression + Nothing                         0.853700
# Stochastic Gradient Descent Regression + Nothing            0.672103
# Linear Regression + Lexical                                 0.797818
# Ridge Regression + Lexical                                  0.797809
# Lasso Regression + Lexical                                  0.844252
# LARS Lasso Regression + Lexical                             0.844252
# Bayesian Ridge Regression + Lexical                         0.798528
# Stochastic Gradient Descent Regression + Lexical            0.631087
# Linear Regression + Scores                                  0.825596
# Ridge Regression + Scores                                   0.837291
# Lasso Regression + Scores                                   0.886985
# LARS Lasso Regression + Scores                              0.886985
# Bayesian Ridge Regression + Scores                          0.835038
# Stochastic Gradient Descent Regression + Scores             0.662697
# Linear Regression + Reading                                 0.753231
# Ridge Regression + Reading                                  0.753230
# Lasso Regression + Reading                                  0.868053
# LARS Lasso Regression + Reading                             0.868053
# Bayesian Ridge Regression + Reading                         0.753193
# Stochastic Gradient Descent Regression + Reading            0.591577
# Linear Regression + NLP                                     0.843679
# Ridge Regression + NLP                                      0.843679
# Lasso Regression + NLP                                      0.878059
# LARS Lasso Regression + NLP                                 0.878059
# Bayesian Ridge Regression + NLP                             0.843718
# Stochastic Gradient Descent Regression + NLP                0.664379
# Linear Regression + All                                     0.716583
# Ridge Regression + All                                      0.718156
# Lasso Regression + All                                      0.811038
# LARS Lasso Regression + All                                 0.811038
# Bayesian Ridge Regression + All                             0.718780
# Stochastic Gradient Descent Regression + All                0.564468
#
#                                                   Mean Absolute Error  \
# Linear Regression + Nothing                                  0.646910
# Ridge Regression + Nothing                                   0.646909
# Lasso Regression + Nothing                                   0.660417
# LARS Lasso Regression + Nothing                              0.660417
# Bayesian Ridge Regression + Nothing                          0.647321
# Stochastic Gradient Descent Regression + Nothing             0.572950
# Linear Regression + Lexical                                  0.627469
# Ridge Regression + Lexical                                   0.627569
# Lasso Regression + Lexical                                   0.658328
# LARS Lasso Regression + Lexical                              0.658327
# Bayesian Ridge Regression + Lexical                          0.626383
# Stochastic Gradient Descent Regression + Lexical             0.553917
# Linear Regression + Scores                                   0.641325
# Ridge Regression + Scores                                    0.647369
# Lasso Regression + Scores                                    0.670088
# LARS Lasso Regression + Scores                               0.670088
# Bayesian Ridge Regression + Scores                           0.643287
# Stochastic Gradient Descent Regression + Scores              0.576154
# Linear Regression + Reading                                  0.618510
# Ridge Regression + Reading                                   0.618509
# Lasso Regression + Reading                                   0.658865
# LARS Lasso Regression + Reading                              0.658864
# Bayesian Ridge Regression + Reading                          0.617701
# Stochastic Gradient Descent Regression + Reading             0.548467
# Linear Regression + NLP                                      0.647948
# Ridge Regression + NLP                                       0.647939
# Lasso Regression + NLP                                       0.660417
# LARS Lasso Regression + NLP                                  0.660417
# Bayesian Ridge Regression + NLP                              0.647459
# Stochastic Gradient Descent Regression + NLP                 0.575144
# Linear Regression + All                                      0.591985
# Ridge Regression + All                                       0.593553
# Lasso Regression + All                                       0.627922
# LARS Lasso Regression + All                                  0.627924
# Bayesian Ridge Regression + All                              0.590547
# Stochastic Gradient Descent Regression + All                 0.527515
#
#                                                   Max Error
# Linear Regression + Nothing                        4.069749
# Ridge Regression + Nothing                         4.069743
# Lasso Regression + Nothing                         4.009325
# LARS Lasso Regression + Nothing                    4.009328
# Bayesian Ridge Regression + Nothing                4.069349
# Stochastic Gradient Descent Regression + Nothing   3.673842
# Linear Regression + Lexical                        3.367063
# Ridge Regression + Lexical                         3.366594
# Lasso Regression + Lexical                         3.451760
# LARS Lasso Regression + Lexical                    3.451758
# Bayesian Ridge Regression + Lexical                3.357252
# Stochastic Gradient Descent Regression + Lexical   3.098743
# Linear Regression + Scores                         3.013166
# Ridge Regression + Scores                          3.290670
# Lasso Regression + Scores                          3.551687
# LARS Lasso Regression + Scores                     3.551690
# Bayesian Ridge Regression + Scores                 3.336508
# Stochastic Gradient Descent Regression + Scores    2.948103
# Linear Regression + Reading                        2.791561
# Ridge Regression + Reading                         2.791599
# Lasso Regression + Reading                         3.584759
# LARS Lasso Regression + Reading                    3.584759
# Bayesian Ridge Regression + Reading                2.806284
# Stochastic Gradient Descent Regression + Reading   2.482688
# Linear Regression + NLP                            3.966111
# Ridge Regression + NLP                             3.966116
# Lasso Regression + NLP                             4.009325
# LARS Lasso Regression + NLP                        4.009328
# Bayesian Ridge Regression + NLP                    3.968905
# Stochastic Gradient Descent Regression + NLP       3.462673
# Linear Regression + All                            3.164138
# Ridge Regression + All                             3.284075
# Lasso Regression + All                             3.704123
# LARS Lasso Regression + All                        3.704155
# Bayesian Ridge Regression + All                    3.324117
# Stochastic Gradient Descent Regression + All       2.937687

# %%
combined_table["R Squared"] = combined_table["R Squared"].apply(lambda x: round(x, 4 - int(math.floor(math.log10(abs(x))))))
combined_table
# Out:
#                                                   R Squared  \
# Linear Regression + Nothing                         0.33462
# Ridge Regression + Nothing                          0.33462
# Lasso Regression + Nothing                          0.31551
# LARS Lasso Regression + Nothing                     0.31551
# Bayesian Ridge Regression + Nothing                 0.33459
# Stochastic Gradient Descent Regression + Nothing    0.32774
# Linear Regression + Lexical                         0.37468
# Ridge Regression + Lexical                          0.37469
# Lasso Regression + Lexical                          0.33795
# LARS Lasso Regression + Lexical                     0.33795
# Bayesian Ridge Regression + Lexical                 0.37411
# Stochastic Gradient Descent Regression + Lexical    0.36822
# Linear Regression + Scores                          0.35245
# Ridge Regression + Scores                           0.34333
# Lasso Regression + Scores                           0.30427
# LARS Lasso Regression + Scores                      0.30427
# Bayesian Ridge Regression + Scores                  0.34499
# Stochastic Gradient Descent Regression + Scores     0.33608
# Linear Regression + Reading                         0.40928
# Ridge Regression + Reading                          0.40928
# Lasso Regression + Reading                          0.31918
# LARS Lasso Regression + Reading                     0.31918
# Bayesian Ridge Regression + Reading                 0.40932
# Stochastic Gradient Descent Regression + Reading    0.40732
# Linear Regression + NLP                             0.34237
# Ridge Regression + NLP                              0.34237
# Lasso Regression + NLP                              0.31551
# LARS Lasso Regression + NLP                         0.31551
# Bayesian Ridge Regression + NLP                     0.34234
# Stochastic Gradient Descent Regression + NLP        0.33545
# Linear Regression + All                             0.44111
# Ridge Regression + All                              0.43992
# Lasso Regression + All                              0.36771
# LARS Lasso Regression + All                         0.36771
# Bayesian Ridge Regression + All                     0.43947
# Stochastic Gradient Descent Regression + All        0.43503
#
#                                                   Mean Squared Error  \
# Linear Regression + Nothing                                 0.853666
# Ridge Regression + Nothing                                  0.853666
# Lasso Regression + Nothing                                  0.878059
# LARS Lasso Regression + Nothing                             0.878059
# Bayesian Ridge Regression + Nothing                         0.853700
# Stochastic Gradient Descent Regression + Nothing            0.672103
# Linear Regression + Lexical                                 0.797818
# Ridge Regression + Lexical                                  0.797809
# Lasso Regression + Lexical                                  0.844252
# LARS Lasso Regression + Lexical                             0.844252
# Bayesian Ridge Regression + Lexical                         0.798528
# Stochastic Gradient Descent Regression + Lexical            0.631087
# Linear Regression + Scores                                  0.825596
# Ridge Regression + Scores                                   0.837291
# Lasso Regression + Scores                                   0.886985
# LARS Lasso Regression + Scores                              0.886985
# Bayesian Ridge Regression + Scores                          0.835038
# Stochastic Gradient Descent Regression + Scores             0.662697
# Linear Regression + Reading                                 0.753231
# Ridge Regression + Reading                                  0.753230
# Lasso Regression + Reading                                  0.868053
# LARS Lasso Regression + Reading                             0.868053
# Bayesian Ridge Regression + Reading                         0.753193
# Stochastic Gradient Descent Regression + Reading            0.591577
# Linear Regression + NLP                                     0.843679
# Ridge Regression + NLP                                      0.843679
# Lasso Regression + NLP                                      0.878059
# LARS Lasso Regression + NLP                                 0.878059
# Bayesian Ridge Regression + NLP                             0.843718
# Stochastic Gradient Descent Regression + NLP                0.664379
# Linear Regression + All                                     0.716583
# Ridge Regression + All                                      0.718156
# Lasso Regression + All                                      0.811038
# LARS Lasso Regression + All                                 0.811038
# Bayesian Ridge Regression + All                             0.718780
# Stochastic Gradient Descent Regression + All                0.564468
#
#                                                   Mean Absolute Error  \
# Linear Regression + Nothing                                  0.646910
# Ridge Regression + Nothing                                   0.646909
# Lasso Regression + Nothing                                   0.660417
# LARS Lasso Regression + Nothing                              0.660417
# Bayesian Ridge Regression + Nothing                          0.647321
# Stochastic Gradient Descent Regression + Nothing             0.572950
# Linear Regression + Lexical                                  0.627469
# Ridge Regression + Lexical                                   0.627569
# Lasso Regression + Lexical                                   0.658328
# LARS Lasso Regression + Lexical                              0.658327
# Bayesian Ridge Regression + Lexical                          0.626383
# Stochastic Gradient Descent Regression + Lexical             0.553917
# Linear Regression + Scores                                   0.641325
# Ridge Regression + Scores                                    0.647369
# Lasso Regression + Scores                                    0.670088
# LARS Lasso Regression + Scores                               0.670088
# Bayesian Ridge Regression + Scores                           0.643287
# Stochastic Gradient Descent Regression + Scores              0.576154
# Linear Regression + Reading                                  0.618510
# Ridge Regression + Reading                                   0.618509
# Lasso Regression + Reading                                   0.658865
# LARS Lasso Regression + Reading                              0.658864
# Bayesian Ridge Regression + Reading                          0.617701
# Stochastic Gradient Descent Regression + Reading             0.548467
# Linear Regression + NLP                                      0.647948
# Ridge Regression + NLP                                       0.647939
# Lasso Regression + NLP                                       0.660417
# LARS Lasso Regression + NLP                                  0.660417
# Bayesian Ridge Regression + NLP                              0.647459
# Stochastic Gradient Descent Regression + NLP                 0.575144
# Linear Regression + All                                      0.591985
# Ridge Regression + All                                       0.593553
# Lasso Regression + All                                       0.627922
# LARS Lasso Regression + All                                  0.627924
# Bayesian Ridge Regression + All                              0.590547
# Stochastic Gradient Descent Regression + All                 0.527515
#
#                                                   Max Error
# Linear Regression + Nothing                        4.069749
# Ridge Regression + Nothing                         4.069743
# Lasso Regression + Nothing                         4.009325
# LARS Lasso Regression + Nothing                    4.009328
# Bayesian Ridge Regression + Nothing                4.069349
# Stochastic Gradient Descent Regression + Nothing   3.673842
# Linear Regression + Lexical                        3.367063
# Ridge Regression + Lexical                         3.366594
# Lasso Regression + Lexical                         3.451760
# LARS Lasso Regression + Lexical                    3.451758
# Bayesian Ridge Regression + Lexical                3.357252
# Stochastic Gradient Descent Regression + Lexical   3.098743
# Linear Regression + Scores                         3.013166
# Ridge Regression + Scores                          3.290670
# Lasso Regression + Scores                          3.551687
# LARS Lasso Regression + Scores                     3.551690
# Bayesian Ridge Regression + Scores                 3.336508
# Stochastic Gradient Descent Regression + Scores    2.948103
# Linear Regression + Reading                        2.791561
# Ridge Regression + Reading                         2.791599
# Lasso Regression + Reading                         3.584759
# LARS Lasso Regression + Reading                    3.584759
# Bayesian Ridge Regression + Reading                2.806284
# Stochastic Gradient Descent Regression + Reading   2.482688
# Linear Regression + NLP                            3.966111
# Ridge Regression + NLP                             3.966116
# Lasso Regression + NLP                             4.009325
# LARS Lasso Regression + NLP                        4.009328
# Bayesian Ridge Regression + NLP                    3.968905
# Stochastic Gradient Descent Regression + NLP       3.462673
# Linear Regression + All                            3.164138
# Ridge Regression + All                             3.284075
# Lasso Regression + All                             3.704123
# LARS Lasso Regression + All                        3.704155
# Bayesian Ridge Regression + All                    3.324117
# Stochastic Gradient Descent Regression + All       2.937687
